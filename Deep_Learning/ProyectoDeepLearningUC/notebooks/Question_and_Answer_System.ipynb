# %% [markdown]
# # Question answering system
#
# Question answering is a computer science discipline within the fields of information retrieval and natural language processing, which is concerned with building systems that automatically answer questions posed by humans in a natural language.

# %% [markdown]
# ![qa.png](qa.png)

# %% [markdown]
# The objective here is to build a Question answering system using the seq2seq approach.

# %% [markdown]
# ### SQuAD Dataset
#
# Stanford Question Answering Dataset (SQuAD) is a reading comprehension dataset, consisting of questions posed by crowdworkers on a set of Wikipedia articles, where the answer to every question is a segment of text, or span, from the corresponding reading passage, or the question might be unanswerable.
#
# We can download the dataset from [here](https://rajpurkar.github.io/SQuAD-explorer/)

# %%
# Importing packages
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

from collections import Counter
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Permute, dot, add, concatenate
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, Activation,RepeatVector
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import History
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## 1. Getting Data

# %%
# !wget "https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json"
# !wget "https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json"
# Out:
# --2021-07-19 00:56:36--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.111.153, 185.199.110.153, 185.199.108.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘train-v2.0.json’
#
# train-v2.0.json     100%[===================>]  40.17M   123MB/s    in 0.3s
#
# 2021-07-19 00:56:38 (123 MB/s) - ‘train-v2.0.json’ saved [42123633/42123633]
#
# --2021-07-19 00:56:38--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.111.153, 185.199.110.153, 185.199.108.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.111.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4370528 (4.2M) [application/json]
# Saving to: ‘dev-v2.0.json’
#
# dev-v2.0.json       100%[===================>]   4.17M  --.-KB/s    in 0.1s
#
# 2021-07-19 00:56:38 (31.4 MB/s) - ‘dev-v2.0.json’ saved [4370528/4370528]

# %%
% cd content
# Out:
# [Errno 2] No such file or directory: 'content'
# /content

# %%
with open("train-v2.0.json",mode="rt",encoding="utf-8") as file:
    qa_data = json.load(file)

# %%
#qa_data["data"][0]['paragraphs'][0]["qas"][0]["question"]
#qa_data["data"][0]['paragraphs'][0]["qas"][0]["answers"]

# %% [markdown]
# ## 2. Pre-processing

# %%
lookup = 'abcdefghijklmnopqrstuvwxyz1234567890?.,'
# check for valid characters
def in_white_list(_word):
    valid_word = False
    for char in _word:
        if char in lookup:
            valid_word = True
            break

    if valid_word is False:
        return False

    return True

# %%
# extract paragraphs,question and answers from SQuAD_data
def get_SQuAD_data(qa_data,max_data_count,max_context_seq_length,max_question_seq_length,max_target_seq_length):
    data = list()
    for instance in qa_data['data']:
        for paragraph in instance['paragraphs']:
            context = paragraph['context']
            context_wid_list = [w.lower() for w in nltk.word_tokenize(context) if in_white_list(w)]
            if len(context_wid_list) > max_context_seq_length:
                continue
            qas = paragraph['qas']
            for qas_instance in qas:
                question = qas_instance['question']
                question_wid_list = [w.lower() for w in nltk.word_tokenize(question) if in_white_list(w)]
                if len(question_wid_list) > max_question_seq_length:
                    continue
                answers = qas_instance['answers']
                for answer in answers:
                    ans = answer['text']
                    answer_wid_list = [w.lower() for w in nltk.word_tokenize(ans) if in_white_list(w)]
                    if len(answer_wid_list) > max_target_seq_length:
                        continue
                    if len(data) < max_data_count:
                        data.append((context, question, ans))

            if len(data) >= max_data_count:
                break

            break
    return data

# %%
max_data_count = 10000
max_context_seq_length = 300
max_question_seq_length = 60
max_target_seq_length = 50
data = get_SQuAD_data(qa_data,max_data_count,max_context_seq_length,max_question_seq_length,max_target_seq_length)
print("Total Q&A data size",len(data))
# Out:
# Total Q&A data size 2350

# %% [markdown]
# ## 3. Feature Extraction

# %% [markdown]
# ### Create dictionnary
# The first step is to create the dictionnary, it means, the list of all words contained in texts. For each word, we will assign an index to it.

# %%
max_input_vocab_size = 5000
max_target_vocab_size = 5000

input_data_samples = []
output_data_samples = []

input_paragraph_max_seq_length = 0
input_question_max_seq_length = 0
target_max_seq_length = 0

input_paragraph_counter = Counter()
input_question_counter = Counter()
target_counter = Counter()
# iterate over each paragraph, question and answer
for sample in data:
    paragraph, question, answer = sample
    paragraph_word_list = [w.lower() for w in nltk.word_tokenize(paragraph) if in_white_list(w)]
    question_word_list = [w.lower() for w in nltk.word_tokenize(question) if in_white_list(w)]
    answer_word_list = [w.lower() for w in nltk.word_tokenize(answer) if in_white_list(w)]

    output_data = ['START'] + answer_word_list + ['END']

    input_data_samples.append([paragraph_word_list, question_word_list])
    output_data_samples.append(output_data)

    for w in paragraph_word_list:
        input_paragraph_counter[w] += 1
    for w in question_word_list:
        input_question_counter[w] += 1
    for w in output_data:
        target_counter[w] += 1

    input_paragraph_max_seq_length = max(input_paragraph_max_seq_length, len(paragraph_word_list))
    input_question_max_seq_length = max(input_question_max_seq_length, len(question_word_list))
    target_max_seq_length = max(target_max_seq_length, len(output_data))

# %%
input_paragraph_word2idx = dict()
input_question_word2idx = dict()
target_word2idx = dict()

# Mapping from word to index
for idx, word in enumerate(input_paragraph_counter.most_common(max_input_vocab_size)):
    input_paragraph_word2idx[word[0]] = idx + 2
for idx, word in enumerate(input_question_counter.most_common(max_input_vocab_size)):
    input_question_word2idx[word[0]] = idx + 2
for idx, word in enumerate(target_counter.most_common(max_target_vocab_size)):
    target_word2idx[word[0]] = idx + 1

target_word2idx['UNK'] = 0
input_paragraph_word2idx['PAD'] = 0
input_paragraph_word2idx['UNK'] = 1
input_question_word2idx['PAD'] = 0
input_paragraph_word2idx['UNK'] = 1

# Mapping from index to word
input_paragraph_idx2word = dict([(idx, word) for word, idx in input_paragraph_word2idx.items()])
input_question_idx2word = dict([(idx, word) for word, idx in input_question_word2idx.items()])
target_idx2word = dict([(idx, word) for word, idx in target_word2idx.items()])

num_input_paragraph_tokens = len(input_paragraph_idx2word)
num_input_question_tokens = len(input_question_idx2word)
num_target_tokens = len(target_idx2word)

# %% [markdown]
# ### Create sequences
#
# Assign index to each word in texts

# %%
input_encoded_data_samples = []
target_encoded_data_samples = []
# iterate over each text sample from paragraphs, questions and answers
for input_data, output_data in zip(input_data_samples, output_data_samples):
    input_paragraph_encoded_data = []
    input_question_encoded_data = []
    target_encoded_data = []
    input_paragraph_data, input_question_data = input_data
    for word in input_paragraph_data:
        if word in input_paragraph_word2idx:
            input_paragraph_encoded_data.append(input_paragraph_word2idx[word])
        else:
            input_paragraph_encoded_data.append(1)
    for word in input_question_data:
        if word in input_question_word2idx:
            input_question_encoded_data.append(input_question_word2idx[word])
        else:
            input_question_encoded_data.append(1)
    for word in output_data:
        if word in target_word2idx:
            target_encoded_data.append(target_word2idx[word])
        else:
            target_encoded_data.append(0)
    input_encoded_data_samples.append([input_paragraph_encoded_data, input_question_encoded_data])
    target_encoded_data_samples.append(target_encoded_data)

# %%
batch_size = 64
epochs = 200
test_size = 0.2
random_state = 42

# %%
# get train and test samples
x_train, x_test, y_train, y_test = train_test_split(input_encoded_data_samples, target_encoded_data_samples, test_size=test_size,random_state=random_state)

# %%
# train and test generator
def generate_batch(input_paragraph_max_seq_length,input_question_max_seq_length,target_max_seq_length,num_target_tokens, input_data, output_data, batch_size):
    num_batches = len(input_data) // batch_size
    while True:
        for batchIdx in range(0, num_batches):
            start = batchIdx * batch_size
            end = (batchIdx + 1) * batch_size
            encoder_input_paragraph_data_batch = []
            encoder_input_question_data_batch = []
            for input_paragraph_data, input_question_data in input_data[start:end]:
                encoder_input_paragraph_data_batch.append(input_paragraph_data)
                encoder_input_question_data_batch.append(input_question_data)
            encoder_input_paragraph_data_batch = pad_sequences(encoder_input_paragraph_data_batch,
                                                               input_paragraph_max_seq_length)
            encoder_input_question_data_batch = pad_sequences(encoder_input_question_data_batch,
                                                              input_question_max_seq_length)
            decoder_target_data_batch = np.zeros(shape=(batch_size, target_max_seq_length, num_target_tokens))
            decoder_input_data_batch = np.zeros(shape=(batch_size, target_max_seq_length, num_target_tokens))
            for lineIdx, target_wid_list in enumerate(output_data[start:end]):
                for idx, wid in enumerate(target_wid_list):
                    if wid == 0:  # UNKNOWN
                        continue
                    decoder_input_data_batch[lineIdx, idx, wid] = 1
                    if idx > 0:
                        decoder_target_data_batch[lineIdx, idx - 1, wid] = 1
            yield [encoder_input_paragraph_data_batch, encoder_input_question_data_batch,
                   decoder_input_data_batch], decoder_target_data_batch

# %%
# get train and test generators
train_gen = generate_batch(input_paragraph_max_seq_length,input_question_max_seq_length,target_max_seq_length,num_target_tokens, x_train, y_train, batch_size)
test_gen = generate_batch(input_paragraph_max_seq_length,input_question_max_seq_length,target_max_seq_length,num_target_tokens, x_test, y_test, batch_size)

# %%
# get train and test batch size
train_num_batches = len(x_train) // batch_size
test_num_batches = len(x_test) // batch_size

# %% [markdown]
# ## 4. Build the model

# %% [markdown]
# ![encode_decode.jpeg](encode_decode.jpeg)

# %%
def create_model(num_encoder_paragraph_tokens,max_encoder_paragraph_seq_length,
                 num_encoder_question_tokens,max_encoder_question_seq_length,num_decoder_tokens):

    hidden_units = 256
    embed_hidden_units = 100

    context_inputs = Input(shape=(None,), name='context_inputs')
    encoded_context = Embedding(input_dim=num_encoder_paragraph_tokens, output_dim=embed_hidden_units,
                                    input_length=max_encoder_paragraph_seq_length,
                                    name='context_embedding')(context_inputs)
    encoded_context = Dropout(0.3)(encoded_context)

    question_inputs = Input(shape=(None,), name='question_inputs')
    encoded_question = Embedding(input_dim=num_encoder_question_tokens+1, output_dim=embed_hidden_units,
                                     input_length=max_encoder_question_seq_length,
                                     name='question_embedding')(question_inputs)
    encoded_question = Dropout(0.3)(encoded_question)
    encoded_question = LSTM(units=embed_hidden_units, name='question_lstm')(encoded_question)
    encoded_question = RepeatVector(max_encoder_paragraph_seq_length)(encoded_question)

    merged = add([encoded_context, encoded_question])

    encoder_lstm = LSTM(units=hidden_units, return_state=True, name='encoder_lstm')
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(merged)
    encoder_states = [encoder_state_h, encoder_state_c]

    decoder_inputs = Input(shape=(None, num_decoder_tokens), name='decoder_inputs')
    decoder_lstm = LSTM(units=hidden_units, return_state=True, return_sequences=True, name='decoder_lstm')
    decoder_outputs, decoder_state_h, decoder_state_c = decoder_lstm(decoder_inputs,
                                                                         initial_state=encoder_states)
    decoder_dense = Dense(units=num_decoder_tokens, activation='softmax', name='decoder_dense')
    decoder_outputs = decoder_dense(decoder_outputs)

    model = Model([context_inputs, question_inputs, decoder_inputs], decoder_outputs)
    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

    encoder_model = Model([context_inputs, question_inputs], encoder_states)

    decoder_state_inputs = [Input(shape=(hidden_units,)), Input(shape=(hidden_units,))]
    decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_state_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = Model([decoder_inputs] + decoder_state_inputs, [decoder_outputs] + decoder_states)

    return model, encoder_model, decoder_model

# %%
model, encoder_model, decoder_model = create_model(num_input_paragraph_tokens,input_paragraph_max_seq_length,
                 num_input_question_tokens,input_question_max_seq_length,num_target_tokens)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# question_inputs (InputLayer)    [(None, None)]       0
# __________________________________________________________________________________________________
# question_embedding (Embedding)  (None, None, 100)    381500      question_inputs[0][0]
# __________________________________________________________________________________________________
# context_inputs (InputLayer)     [(None, None)]       0
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 100)    0           question_embedding[0][0]
# __________________________________________________________________________________________________
# context_embedding (Embedding)   (None, None, 100)    500200      context_inputs[0][0]
# __________________________________________________________________________________________________
# question_lstm (LSTM)            (None, 100)          80400       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 100)    0           context_embedding[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 298, 100)     0           question_lstm[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 298, 100)     0           dropout[0][0]
#                                                                  repeat_vector[0][0]
# __________________________________________________________________________________________________
# decoder_inputs (InputLayer)     [(None, None, 3227)] 0
# __________________________________________________________________________________________________
# encoder_lstm (LSTM)             [(None, 256), (None, 365568      add[0][0]
# __________________________________________________________________________________________________
# decoder_lstm (LSTM)             [(None, None, 256),  3567616     decoder_inputs[0][0]
#                                                                  encoder_lstm[0][1]
#                                                                  encoder_lstm[0][2]
# __________________________________________________________________________________________________
# decoder_dense (Dense)           (None, None, 3227)   829339      decoder_lstm[0][0]
# ==================================================================================================
# Total params: 5,724,623
# Trainable params: 5,724,623
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)

# %%
# Defining a helper function to save the model after each epoch 
# in which the loss decreases 
filepath = 'model_QandA.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
# Defining a helper function to reduce the learning rate each time 
# the learning plateaus 
reduce_alpha = ReduceLROnPlateau(monitor ='val_loss', factor = 0.2, patience = 1, min_lr = 0.001)
# stop traning if there increase in loss
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)
callbacks = [checkpoint, reduce_alpha]

# %% [markdown]
# ## 5. Train the model

# %%
history = model.fit_generator(generator=train_gen, steps_per_epoch=train_num_batches,
                                           epochs=epochs,
                                           verbose=1, validation_data=test_gen, validation_steps=test_num_batches,
                                           callbacks=callbacks)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/200
# 29/29 [==============================] - 14s 150ms/step - loss: 0.7650 - accuracy: 0.0268 - val_loss: 0.7541 - val_accuracy: 0.0278
#
# Epoch 00001: val_loss improved from inf to 0.75413, saving model to model_QandA.h5
# Epoch 2/200
#  1/29 [>.............................] - ETA: 2s - loss: 0.8669 - accuracy: 0.0278
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 29/29 [==============================] - 3s 102ms/step - loss: 0.7248 - accuracy: 0.0278 - val_loss: 0.7587 - val_accuracy: 0.0278
#
# Epoch 00002: val_loss did not improve from 0.75413
# Epoch 3/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.7241 - accuracy: 0.0278 - val_loss: 0.7631 - val_accuracy: 0.0278
#
# Epoch 00003: val_loss did not improve from 0.75413
# Epoch 4/200
# 29/29 [==============================] - 3s 101ms/step - loss: 0.7241 - accuracy: 0.0278 - val_loss: 0.7673 - val_accuracy: 0.0278
#
# Epoch 00004: val_loss did not improve from 0.75413
# Epoch 5/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7239 - accuracy: 0.0278 - val_loss: 0.7716 - val_accuracy: 0.0278
#
# Epoch 00005: val_loss did not improve from 0.75413
# Epoch 6/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7236 - accuracy: 0.0278 - val_loss: 0.7762 - val_accuracy: 0.0289
#
# Epoch 00006: val_loss did not improve from 0.75413
# Epoch 7/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7235 - accuracy: 0.0292 - val_loss: 0.7807 - val_accuracy: 0.0289
#
# Epoch 00007: val_loss did not improve from 0.75413
# Epoch 8/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.7234 - accuracy: 0.0292 - val_loss: 0.7854 - val_accuracy: 0.0289
#
# Epoch 00008: val_loss did not improve from 0.75413
# Epoch 9/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7233 - accuracy: 0.0292 - val_loss: 0.7902 - val_accuracy: 0.0289
#
# Epoch 00009: val_loss did not improve from 0.75413
# Epoch 10/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7233 - accuracy: 0.0292 - val_loss: 0.7949 - val_accuracy: 0.0289
#
# Epoch 00010: val_loss did not improve from 0.75413
# Epoch 11/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7232 - accuracy: 0.0292 - val_loss: 0.7995 - val_accuracy: 0.0289
#
# Epoch 00011: val_loss did not improve from 0.75413
# Epoch 12/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.7231 - accuracy: 0.0292 - val_loss: 0.8041 - val_accuracy: 0.0289
#
# Epoch 00012: val_loss did not improve from 0.75413
# Epoch 13/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7230 - accuracy: 0.0292 - val_loss: 0.8086 - val_accuracy: 0.0289
#
# Epoch 00013: val_loss did not improve from 0.75413
# Epoch 14/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7229 - accuracy: 0.0292 - val_loss: 0.8131 - val_accuracy: 0.0289
#
# Epoch 00014: val_loss did not improve from 0.75413
# Epoch 15/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7228 - accuracy: 0.0292 - val_loss: 0.8175 - val_accuracy: 0.0289
#
# Epoch 00015: val_loss did not improve from 0.75413
# Epoch 16/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7225 - accuracy: 0.0292 - val_loss: 0.8213 - val_accuracy: 0.0289
#
# Epoch 00016: val_loss did not improve from 0.75413
# Epoch 17/200
# 29/29 [==============================] - 3s 100ms/step - loss: 0.7221 - accuracy: 0.0292 - val_loss: 0.8256 - val_accuracy: 0.0289
#
# Epoch 00017: val_loss did not improve from 0.75413
# Epoch 18/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.7218 - accuracy: 0.0292 - val_loss: 0.8295 - val_accuracy: 0.0289
#
# Epoch 00018: val_loss did not improve from 0.75413
# Epoch 19/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.7210 - accuracy: 0.0292 - val_loss: 0.8324 - val_accuracy: 0.0289
#
# Epoch 00019: val_loss did not improve from 0.75413
# Epoch 20/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7199 - accuracy: 0.0292 - val_loss: 0.8374 - val_accuracy: 0.0289
#
# Epoch 00020: val_loss did not improve from 0.75413
# Epoch 21/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7186 - accuracy: 0.0292 - val_loss: 0.8388 - val_accuracy: 0.0289
#
# Epoch 00021: val_loss did not improve from 0.75413
# Epoch 22/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.7181 - accuracy: 0.0292 - val_loss: 0.8428 - val_accuracy: 0.0289
#
# Epoch 00022: val_loss did not improve from 0.75413
# Epoch 23/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7176 - accuracy: 0.0292 - val_loss: 0.8469 - val_accuracy: 0.0289
#
# Epoch 00023: val_loss did not improve from 0.75413
# Epoch 24/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7173 - accuracy: 0.0292 - val_loss: 0.8490 - val_accuracy: 0.0289
#
# Epoch 00024: val_loss did not improve from 0.75413
# Epoch 25/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7170 - accuracy: 0.0292 - val_loss: 0.8531 - val_accuracy: 0.0289
#
# Epoch 00025: val_loss did not improve from 0.75413
# Epoch 26/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7169 - accuracy: 0.0292 - val_loss: 0.8552 - val_accuracy: 0.0289
#
# Epoch 00026: val_loss did not improve from 0.75413
# Epoch 27/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.7166 - accuracy: 0.0292 - val_loss: 0.8585 - val_accuracy: 0.0289
#
# Epoch 00027: val_loss did not improve from 0.75413
# Epoch 28/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.7166 - accuracy: 0.0292 - val_loss: 0.8631 - val_accuracy: 0.0289
#
# Epoch 00028: val_loss did not improve from 0.75413
# Epoch 29/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7165 - accuracy: 0.0292 - val_loss: 0.8645 - val_accuracy: 0.0289
#
# Epoch 00029: val_loss did not improve from 0.75413
# Epoch 30/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7165 - accuracy: 0.0292 - val_loss: 0.8684 - val_accuracy: 0.0289
#
# Epoch 00030: val_loss did not improve from 0.75413
# Epoch 31/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.7167 - accuracy: 0.0292 - val_loss: 0.8730 - val_accuracy: 0.0289
#
# Epoch 00031: val_loss did not improve from 0.75413
# Epoch 32/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.7161 - accuracy: 0.0292 - val_loss: 0.8737 - val_accuracy: 0.0289
#
# Epoch 00032: val_loss did not improve from 0.75413
# Epoch 33/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.7164 - accuracy: 0.0292 - val_loss: 0.8759 - val_accuracy: 0.0289
#
# Epoch 00033: val_loss did not improve from 0.75413
# Epoch 34/200
# 29/29 [==============================] - 3s 113ms/step - loss: 0.7161 - accuracy: 0.0292 - val_loss: 0.8797 - val_accuracy: 0.0289
#
# Epoch 00034: val_loss did not improve from 0.75413
# Epoch 35/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7163 - accuracy: 0.0292 - val_loss: 0.8808 - val_accuracy: 0.0289
#
# Epoch 00035: val_loss did not improve from 0.75413
# Epoch 36/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7185 - accuracy: 0.0290 - val_loss: 0.8838 - val_accuracy: 0.0289
#
# Epoch 00036: val_loss did not improve from 0.75413
# Epoch 37/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7165 - accuracy: 0.0292 - val_loss: 0.8860 - val_accuracy: 0.0289
#
# Epoch 00037: val_loss did not improve from 0.75413
# Epoch 38/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7157 - accuracy: 0.0293 - val_loss: 0.8895 - val_accuracy: 0.0289
#
# Epoch 00038: val_loss did not improve from 0.75413
# Epoch 39/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7147 - accuracy: 0.0292 - val_loss: 0.8930 - val_accuracy: 0.0288
#
# Epoch 00039: val_loss did not improve from 0.75413
# Epoch 40/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7139 - accuracy: 0.0292 - val_loss: 0.8927 - val_accuracy: 0.0288
#
# Epoch 00040: val_loss did not improve from 0.75413
# Epoch 41/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7127 - accuracy: 0.0291 - val_loss: 0.8964 - val_accuracy: 0.0289
#
# Epoch 00041: val_loss did not improve from 0.75413
# Epoch 42/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7119 - accuracy: 0.0291 - val_loss: 0.8985 - val_accuracy: 0.0288
#
# Epoch 00042: val_loss did not improve from 0.75413
# Epoch 43/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7113 - accuracy: 0.0291 - val_loss: 0.8982 - val_accuracy: 0.0288
#
# Epoch 00043: val_loss did not improve from 0.75413
# Epoch 44/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7106 - accuracy: 0.0291 - val_loss: 0.9015 - val_accuracy: 0.0288
#
# Epoch 00044: val_loss did not improve from 0.75413
# Epoch 45/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.7100 - accuracy: 0.0291 - val_loss: 0.9040 - val_accuracy: 0.0289
#
# Epoch 00045: val_loss did not improve from 0.75413
# Epoch 46/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7095 - accuracy: 0.0291 - val_loss: 0.9027 - val_accuracy: 0.0287
#
# Epoch 00046: val_loss did not improve from 0.75413
# Epoch 47/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7090 - accuracy: 0.0292 - val_loss: 0.9081 - val_accuracy: 0.0288
#
# Epoch 00047: val_loss did not improve from 0.75413
# Epoch 48/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.7084 - accuracy: 0.0293 - val_loss: 0.9087 - val_accuracy: 0.0288
#
# Epoch 00048: val_loss did not improve from 0.75413
# Epoch 49/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7078 - accuracy: 0.0291 - val_loss: 0.9093 - val_accuracy: 0.0288
#
# Epoch 00049: val_loss did not improve from 0.75413
# Epoch 50/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7075 - accuracy: 0.0292 - val_loss: 0.9130 - val_accuracy: 0.0289
#
# Epoch 00050: val_loss did not improve from 0.75413
# Epoch 51/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7070 - accuracy: 0.0292 - val_loss: 0.9155 - val_accuracy: 0.0289
#
# Epoch 00051: val_loss did not improve from 0.75413
# Epoch 52/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7066 - accuracy: 0.0293 - val_loss: 0.9159 - val_accuracy: 0.0288
#
# Epoch 00052: val_loss did not improve from 0.75413
# Epoch 53/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7061 - accuracy: 0.0293 - val_loss: 0.9174 - val_accuracy: 0.0287
#
# Epoch 00053: val_loss did not improve from 0.75413
# Epoch 54/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.7059 - accuracy: 0.0293 - val_loss: 0.9204 - val_accuracy: 0.0286
#
# Epoch 00054: val_loss did not improve from 0.75413
# Epoch 55/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.7054 - accuracy: 0.0294 - val_loss: 0.9207 - val_accuracy: 0.0285
#
# Epoch 00055: val_loss did not improve from 0.75413
# Epoch 56/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.7052 - accuracy: 0.0293 - val_loss: 0.9167 - val_accuracy: 0.0284
#
# Epoch 00056: val_loss did not improve from 0.75413
# Epoch 57/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7047 - accuracy: 0.0294 - val_loss: 0.9215 - val_accuracy: 0.0286
#
# Epoch 00057: val_loss did not improve from 0.75413
# Epoch 58/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7047 - accuracy: 0.0293 - val_loss: 0.9236 - val_accuracy: 0.0285
#
# Epoch 00058: val_loss did not improve from 0.75413
# Epoch 59/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7040 - accuracy: 0.0293 - val_loss: 0.9293 - val_accuracy: 0.0283
#
# Epoch 00059: val_loss did not improve from 0.75413
# Epoch 60/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7039 - accuracy: 0.0294 - val_loss: 0.9230 - val_accuracy: 0.0285
#
# Epoch 00060: val_loss did not improve from 0.75413
# Epoch 61/200
# 29/29 [==============================] - 3s 111ms/step - loss: 0.7035 - accuracy: 0.0294 - val_loss: 0.9221 - val_accuracy: 0.0286
#
# Epoch 00061: val_loss did not improve from 0.75413
# Epoch 62/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.7033 - accuracy: 0.0294 - val_loss: 0.9325 - val_accuracy: 0.0284
#
# Epoch 00062: val_loss did not improve from 0.75413
# Epoch 63/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7028 - accuracy: 0.0294 - val_loss: 0.9266 - val_accuracy: 0.0284
#
# Epoch 00063: val_loss did not improve from 0.75413
# Epoch 64/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.7025 - accuracy: 0.0294 - val_loss: 0.9333 - val_accuracy: 0.0284
#
# Epoch 00064: val_loss did not improve from 0.75413
# Epoch 65/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7020 - accuracy: 0.0294 - val_loss: 0.9302 - val_accuracy: 0.0284
#
# Epoch 00065: val_loss did not improve from 0.75413
# Epoch 66/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7020 - accuracy: 0.0295 - val_loss: 0.9218 - val_accuracy: 0.0285
#
# Epoch 00066: val_loss did not improve from 0.75413
# Epoch 67/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7015 - accuracy: 0.0295 - val_loss: 0.9371 - val_accuracy: 0.0285
#
# Epoch 00067: val_loss did not improve from 0.75413
# Epoch 68/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.7015 - accuracy: 0.0294 - val_loss: 0.9331 - val_accuracy: 0.0283
#
# Epoch 00068: val_loss did not improve from 0.75413
# Epoch 69/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.7008 - accuracy: 0.0295 - val_loss: 0.9359 - val_accuracy: 0.0283
#
# Epoch 00069: val_loss did not improve from 0.75413
# Epoch 70/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7006 - accuracy: 0.0295 - val_loss: 0.9297 - val_accuracy: 0.0284
#
# Epoch 00070: val_loss did not improve from 0.75413
# Epoch 71/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7003 - accuracy: 0.0295 - val_loss: 0.9362 - val_accuracy: 0.0282
#
# Epoch 00071: val_loss did not improve from 0.75413
# Epoch 72/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6999 - accuracy: 0.0295 - val_loss: 0.9290 - val_accuracy: 0.0284
#
# Epoch 00072: val_loss did not improve from 0.75413
# Epoch 73/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6995 - accuracy: 0.0294 - val_loss: 0.9398 - val_accuracy: 0.0282
#
# Epoch 00073: val_loss did not improve from 0.75413
# Epoch 74/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6992 - accuracy: 0.0295 - val_loss: 0.9295 - val_accuracy: 0.0283
#
# Epoch 00074: val_loss did not improve from 0.75413
# Epoch 75/200
# 29/29 [==============================] - 3s 111ms/step - loss: 0.6987 - accuracy: 0.0294 - val_loss: 0.9359 - val_accuracy: 0.0283
#
# Epoch 00075: val_loss did not improve from 0.75413
# Epoch 76/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6985 - accuracy: 0.0294 - val_loss: 0.9418 - val_accuracy: 0.0283
#
# Epoch 00076: val_loss did not improve from 0.75413
# Epoch 77/200
# 29/29 [==============================] - 3s 114ms/step - loss: 0.6983 - accuracy: 0.0294 - val_loss: 0.9358 - val_accuracy: 0.0283
#
# Epoch 00077: val_loss did not improve from 0.75413
# Epoch 78/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6976 - accuracy: 0.0295 - val_loss: 0.9424 - val_accuracy: 0.0282
#
# Epoch 00078: val_loss did not improve from 0.75413
# Epoch 79/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.7301 - accuracy: 0.0269 - val_loss: 0.9225 - val_accuracy: 0.0278
#
# Epoch 00079: val_loss did not improve from 0.75413
# Epoch 80/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.7112 - accuracy: 0.0282 - val_loss: 0.9254 - val_accuracy: 0.0280
#
# Epoch 00080: val_loss did not improve from 0.75413
# Epoch 81/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.7050 - accuracy: 0.0284 - val_loss: 0.9297 - val_accuracy: 0.0281
#
# Epoch 00081: val_loss did not improve from 0.75413
# Epoch 82/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.7003 - accuracy: 0.0288 - val_loss: 0.9329 - val_accuracy: 0.0283
#
# Epoch 00082: val_loss did not improve from 0.75413
# Epoch 83/200
# 29/29 [==============================] - 3s 112ms/step - loss: 0.6978 - accuracy: 0.0293 - val_loss: 0.9328 - val_accuracy: 0.0283
#
# Epoch 00083: val_loss did not improve from 0.75413
# Epoch 84/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6980 - accuracy: 0.0293 - val_loss: 0.9357 - val_accuracy: 0.0284
#
# Epoch 00084: val_loss did not improve from 0.75413
# Epoch 85/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6980 - accuracy: 0.0295 - val_loss: 0.9302 - val_accuracy: 0.0283
#
# Epoch 00085: val_loss did not improve from 0.75413
# Epoch 86/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6963 - accuracy: 0.0295 - val_loss: 0.9337 - val_accuracy: 0.0283
#
# Epoch 00086: val_loss did not improve from 0.75413
# Epoch 87/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6955 - accuracy: 0.0296 - val_loss: 0.9372 - val_accuracy: 0.0283
#
# Epoch 00087: val_loss did not improve from 0.75413
# Epoch 88/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6949 - accuracy: 0.0296 - val_loss: 0.9308 - val_accuracy: 0.0284
#
# Epoch 00088: val_loss did not improve from 0.75413
# Epoch 89/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6945 - accuracy: 0.0295 - val_loss: 0.9399 - val_accuracy: 0.0283
#
# Epoch 00089: val_loss did not improve from 0.75413
# Epoch 90/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6942 - accuracy: 0.0294 - val_loss: 0.9422 - val_accuracy: 0.0283
#
# Epoch 00090: val_loss did not improve from 0.75413
# Epoch 91/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6940 - accuracy: 0.0294 - val_loss: 0.9411 - val_accuracy: 0.0283
#
# Epoch 00091: val_loss did not improve from 0.75413
# Epoch 92/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6931 - accuracy: 0.0294 - val_loss: 0.9391 - val_accuracy: 0.0283
#
# Epoch 00092: val_loss did not improve from 0.75413
# Epoch 93/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6926 - accuracy: 0.0295 - val_loss: 0.9416 - val_accuracy: 0.0283
#
# Epoch 00093: val_loss did not improve from 0.75413
# Epoch 94/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6923 - accuracy: 0.0295 - val_loss: 0.9438 - val_accuracy: 0.0284
#
# Epoch 00094: val_loss did not improve from 0.75413
# Epoch 95/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6920 - accuracy: 0.0295 - val_loss: 0.9363 - val_accuracy: 0.0284
#
# Epoch 00095: val_loss did not improve from 0.75413
# Epoch 96/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6917 - accuracy: 0.0295 - val_loss: 0.9403 - val_accuracy: 0.0284
#
# Epoch 00096: val_loss did not improve from 0.75413
# Epoch 97/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6912 - accuracy: 0.0295 - val_loss: 0.9461 - val_accuracy: 0.0283
#
# Epoch 00097: val_loss did not improve from 0.75413
# Epoch 98/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6907 - accuracy: 0.0295 - val_loss: 0.9323 - val_accuracy: 0.0283
#
# Epoch 00098: val_loss did not improve from 0.75413
# Epoch 99/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6904 - accuracy: 0.0294 - val_loss: 0.9497 - val_accuracy: 0.0283
#
# Epoch 00099: val_loss did not improve from 0.75413
# Epoch 100/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6900 - accuracy: 0.0295 - val_loss: 0.9453 - val_accuracy: 0.0283
#
# Epoch 00100: val_loss did not improve from 0.75413
# Epoch 101/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6896 - accuracy: 0.0295 - val_loss: 0.9406 - val_accuracy: 0.0283
#
# Epoch 00101: val_loss did not improve from 0.75413
# Epoch 102/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.6889 - accuracy: 0.0296 - val_loss: 0.9473 - val_accuracy: 0.0283
#
# Epoch 00102: val_loss did not improve from 0.75413
# Epoch 103/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6888 - accuracy: 0.0295 - val_loss: 0.9446 - val_accuracy: 0.0283
#
# Epoch 00103: val_loss did not improve from 0.75413
# Epoch 104/200
# 29/29 [==============================] - 3s 112ms/step - loss: 0.6883 - accuracy: 0.0295 - val_loss: 0.9420 - val_accuracy: 0.0283
#
# Epoch 00104: val_loss did not improve from 0.75413
# Epoch 105/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6879 - accuracy: 0.0296 - val_loss: 0.9514 - val_accuracy: 0.0284
#
# Epoch 00105: val_loss did not improve from 0.75413
# Epoch 106/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6874 - accuracy: 0.0295 - val_loss: 0.9445 - val_accuracy: 0.0284
#
# Epoch 00106: val_loss did not improve from 0.75413
# Epoch 107/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6870 - accuracy: 0.0296 - val_loss: 0.9482 - val_accuracy: 0.0284
#
# Epoch 00107: val_loss did not improve from 0.75413
# Epoch 108/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6865 - accuracy: 0.0296 - val_loss: 0.9442 - val_accuracy: 0.0283
#
# Epoch 00108: val_loss did not improve from 0.75413
# Epoch 109/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6863 - accuracy: 0.0295 - val_loss: 0.9492 - val_accuracy: 0.0283
#
# Epoch 00109: val_loss did not improve from 0.75413
# Epoch 110/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6857 - accuracy: 0.0296 - val_loss: 0.9514 - val_accuracy: 0.0283
#
# Epoch 00110: val_loss did not improve from 0.75413
# Epoch 111/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6854 - accuracy: 0.0296 - val_loss: 0.9482 - val_accuracy: 0.0283
#
# Epoch 00111: val_loss did not improve from 0.75413
# Epoch 112/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6849 - accuracy: 0.0297 - val_loss: 0.9435 - val_accuracy: 0.0283
#
# Epoch 00112: val_loss did not improve from 0.75413
# Epoch 113/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6846 - accuracy: 0.0297 - val_loss: 0.9482 - val_accuracy: 0.0284
#
# Epoch 00113: val_loss did not improve from 0.75413
# Epoch 114/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6840 - accuracy: 0.0297 - val_loss: 0.9446 - val_accuracy: 0.0284
#
# Epoch 00114: val_loss did not improve from 0.75413
# Epoch 115/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6836 - accuracy: 0.0296 - val_loss: 0.9511 - val_accuracy: 0.0284
#
# Epoch 00115: val_loss did not improve from 0.75413
# Epoch 116/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6834 - accuracy: 0.0296 - val_loss: 0.9450 - val_accuracy: 0.0285
#
# Epoch 00116: val_loss did not improve from 0.75413
# Epoch 117/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.6828 - accuracy: 0.0297 - val_loss: 0.9536 - val_accuracy: 0.0284
#
# Epoch 00117: val_loss did not improve from 0.75413
# Epoch 118/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6824 - accuracy: 0.0297 - val_loss: 0.9433 - val_accuracy: 0.0284
#
# Epoch 00118: val_loss did not improve from 0.75413
# Epoch 119/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.6823 - accuracy: 0.0296 - val_loss: 0.9550 - val_accuracy: 0.0285
#
# Epoch 00119: val_loss did not improve from 0.75413
# Epoch 120/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6816 - accuracy: 0.0297 - val_loss: 0.9477 - val_accuracy: 0.0283
#
# Epoch 00120: val_loss did not improve from 0.75413
# Epoch 121/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6813 - accuracy: 0.0297 - val_loss: 0.9503 - val_accuracy: 0.0284
#
# Epoch 00121: val_loss did not improve from 0.75413
# Epoch 122/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6809 - accuracy: 0.0297 - val_loss: 0.9561 - val_accuracy: 0.0284
#
# Epoch 00122: val_loss did not improve from 0.75413
# Epoch 123/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6803 - accuracy: 0.0297 - val_loss: 0.9469 - val_accuracy: 0.0284
#
# Epoch 00123: val_loss did not improve from 0.75413
# Epoch 124/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6804 - accuracy: 0.0297 - val_loss: 0.9470 - val_accuracy: 0.0284
#
# Epoch 00124: val_loss did not improve from 0.75413
# Epoch 125/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6799 - accuracy: 0.0297 - val_loss: 0.9555 - val_accuracy: 0.0285
#
# Epoch 00125: val_loss did not improve from 0.75413
# Epoch 126/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.6795 - accuracy: 0.0298 - val_loss: 0.9513 - val_accuracy: 0.0284
#
# Epoch 00126: val_loss did not improve from 0.75413
# Epoch 127/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6792 - accuracy: 0.0297 - val_loss: 0.9565 - val_accuracy: 0.0285
#
# Epoch 00127: val_loss did not improve from 0.75413
# Epoch 128/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6789 - accuracy: 0.0297 - val_loss: 0.9633 - val_accuracy: 0.0285
#
# Epoch 00128: val_loss did not improve from 0.75413
# Epoch 129/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.6783 - accuracy: 0.0297 - val_loss: 0.9541 - val_accuracy: 0.0284
#
# Epoch 00129: val_loss did not improve from 0.75413
# Epoch 130/200
# 29/29 [==============================] - 3s 111ms/step - loss: 0.6784 - accuracy: 0.0297 - val_loss: 0.9599 - val_accuracy: 0.0283
#
# Epoch 00130: val_loss did not improve from 0.75413
# Epoch 131/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6777 - accuracy: 0.0298 - val_loss: 0.9590 - val_accuracy: 0.0282
#
# Epoch 00131: val_loss did not improve from 0.75413
# Epoch 132/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6776 - accuracy: 0.0299 - val_loss: 0.9549 - val_accuracy: 0.0282
#
# Epoch 00132: val_loss did not improve from 0.75413
# Epoch 133/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6771 - accuracy: 0.0299 - val_loss: 0.9642 - val_accuracy: 0.0281
#
# Epoch 00133: val_loss did not improve from 0.75413
# Epoch 134/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6770 - accuracy: 0.0299 - val_loss: 0.9583 - val_accuracy: 0.0281
#
# Epoch 00134: val_loss did not improve from 0.75413
# Epoch 135/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.6766 - accuracy: 0.0299 - val_loss: 0.9679 - val_accuracy: 0.0281
#
# Epoch 00135: val_loss did not improve from 0.75413
# Epoch 136/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6762 - accuracy: 0.0300 - val_loss: 0.9586 - val_accuracy: 0.0280
#
# Epoch 00136: val_loss did not improve from 0.75413
# Epoch 137/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6762 - accuracy: 0.0300 - val_loss: 0.9674 - val_accuracy: 0.0281
#
# Epoch 00137: val_loss did not improve from 0.75413
# Epoch 138/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6754 - accuracy: 0.0301 - val_loss: 0.9668 - val_accuracy: 0.0281
#
# Epoch 00138: val_loss did not improve from 0.75413
# Epoch 139/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6754 - accuracy: 0.0302 - val_loss: 0.9686 - val_accuracy: 0.0281
#
# Epoch 00139: val_loss did not improve from 0.75413
# Epoch 140/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6751 - accuracy: 0.0302 - val_loss: 0.9641 - val_accuracy: 0.0282
#
# Epoch 00140: val_loss did not improve from 0.75413
# Epoch 141/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6747 - accuracy: 0.0301 - val_loss: 0.9715 - val_accuracy: 0.0281
#
# Epoch 00141: val_loss did not improve from 0.75413
# Epoch 142/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6746 - accuracy: 0.0301 - val_loss: 0.9720 - val_accuracy: 0.0281
#
# Epoch 00142: val_loss did not improve from 0.75413
# Epoch 143/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6743 - accuracy: 0.0301 - val_loss: 0.9754 - val_accuracy: 0.0281
#
# Epoch 00143: val_loss did not improve from 0.75413
# Epoch 144/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6738 - accuracy: 0.0300 - val_loss: 0.9724 - val_accuracy: 0.0281
#
# Epoch 00144: val_loss did not improve from 0.75413
# Epoch 145/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6736 - accuracy: 0.0301 - val_loss: 0.9641 - val_accuracy: 0.0281
#
# Epoch 00145: val_loss did not improve from 0.75413
# Epoch 146/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.6735 - accuracy: 0.0301 - val_loss: 0.9669 - val_accuracy: 0.0281
#
# Epoch 00146: val_loss did not improve from 0.75413
# Epoch 147/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6732 - accuracy: 0.0301 - val_loss: 0.9763 - val_accuracy: 0.0282
#
# Epoch 00147: val_loss did not improve from 0.75413
# Epoch 148/200
# 29/29 [==============================] - 3s 116ms/step - loss: 0.6727 - accuracy: 0.0302 - val_loss: 0.9784 - val_accuracy: 0.0280
#
# Epoch 00148: val_loss did not improve from 0.75413
# Epoch 149/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6725 - accuracy: 0.0302 - val_loss: 0.9719 - val_accuracy: 0.0282
#
# Epoch 00149: val_loss did not improve from 0.75413
# Epoch 150/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6723 - accuracy: 0.0301 - val_loss: 0.9753 - val_accuracy: 0.0280
#
# Epoch 00150: val_loss did not improve from 0.75413
# Epoch 151/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6720 - accuracy: 0.0300 - val_loss: 0.9723 - val_accuracy: 0.0282
#
# Epoch 00151: val_loss did not improve from 0.75413
# Epoch 152/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.6715 - accuracy: 0.0301 - val_loss: 0.9835 - val_accuracy: 0.0281
#
# Epoch 00152: val_loss did not improve from 0.75413
# Epoch 153/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6715 - accuracy: 0.0300 - val_loss: 0.9838 - val_accuracy: 0.0283
#
# Epoch 00153: val_loss did not improve from 0.75413
# Epoch 154/200
# 29/29 [==============================] - 3s 102ms/step - loss: 0.6710 - accuracy: 0.0301 - val_loss: 0.9787 - val_accuracy: 0.0281
#
# Epoch 00154: val_loss did not improve from 0.75413
# Epoch 155/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6710 - accuracy: 0.0301 - val_loss: 0.9802 - val_accuracy: 0.0281
#
# Epoch 00155: val_loss did not improve from 0.75413
# Epoch 156/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6708 - accuracy: 0.0300 - val_loss: 0.9773 - val_accuracy: 0.0281
#
# Epoch 00156: val_loss did not improve from 0.75413
# Epoch 157/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6705 - accuracy: 0.0300 - val_loss: 0.9821 - val_accuracy: 0.0281
#
# Epoch 00157: val_loss did not improve from 0.75413
# Epoch 158/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6702 - accuracy: 0.0300 - val_loss: 0.9890 - val_accuracy: 0.0281
#
# Epoch 00158: val_loss did not improve from 0.75413
# Epoch 159/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6700 - accuracy: 0.0300 - val_loss: 0.9860 - val_accuracy: 0.0280
#
# Epoch 00159: val_loss did not improve from 0.75413
# Epoch 160/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6699 - accuracy: 0.0299 - val_loss: 0.9834 - val_accuracy: 0.0280
#
# Epoch 00160: val_loss did not improve from 0.75413
# Epoch 161/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6694 - accuracy: 0.0299 - val_loss: 0.9938 - val_accuracy: 0.0280
#
# Epoch 00161: val_loss did not improve from 0.75413
# Epoch 162/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6692 - accuracy: 0.0300 - val_loss: 0.9847 - val_accuracy: 0.0279
#
# Epoch 00162: val_loss did not improve from 0.75413
# Epoch 163/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6692 - accuracy: 0.0299 - val_loss: 0.9935 - val_accuracy: 0.0279
#
# Epoch 00163: val_loss did not improve from 0.75413
# Epoch 164/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6687 - accuracy: 0.0298 - val_loss: 0.9873 - val_accuracy: 0.0280
#
# Epoch 00164: val_loss did not improve from 0.75413
# Epoch 165/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6687 - accuracy: 0.0298 - val_loss: 0.9962 - val_accuracy: 0.0278
#
# Epoch 00165: val_loss did not improve from 0.75413
# Epoch 166/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6685 - accuracy: 0.0298 - val_loss: 0.9783 - val_accuracy: 0.0280
#
# Epoch 00166: val_loss did not improve from 0.75413
# Epoch 167/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.6685 - accuracy: 0.0297 - val_loss: 0.9986 - val_accuracy: 0.0279
#
# Epoch 00167: val_loss did not improve from 0.75413
# Epoch 168/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6678 - accuracy: 0.0298 - val_loss: 0.9905 - val_accuracy: 0.0279
#
# Epoch 00168: val_loss did not improve from 0.75413
# Epoch 169/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6681 - accuracy: 0.0296 - val_loss: 0.9910 - val_accuracy: 0.0278
#
# Epoch 00169: val_loss did not improve from 0.75413
# Epoch 170/200
# 29/29 [==============================] - 3s 111ms/step - loss: 0.6673 - accuracy: 0.0295 - val_loss: 1.0046 - val_accuracy: 0.0278
#
# Epoch 00170: val_loss did not improve from 0.75413
# Epoch 171/200
# 29/29 [==============================] - 3s 111ms/step - loss: 0.6677 - accuracy: 0.0292 - val_loss: 0.9988 - val_accuracy: 0.0278
#
# Epoch 00171: val_loss did not improve from 0.75413
# Epoch 172/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.6670 - accuracy: 0.0291 - val_loss: 0.9959 - val_accuracy: 0.0278
#
# Epoch 00172: val_loss did not improve from 0.75413
# Epoch 173/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6671 - accuracy: 0.0286 - val_loss: 1.0041 - val_accuracy: 0.0277
#
# Epoch 00173: val_loss did not improve from 0.75413
# Epoch 174/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6669 - accuracy: 0.0286 - val_loss: 1.0051 - val_accuracy: 0.0277
#
# Epoch 00174: val_loss did not improve from 0.75413
# Epoch 175/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6665 - accuracy: 0.0286 - val_loss: 1.0096 - val_accuracy: 0.0277
#
# Epoch 00175: val_loss did not improve from 0.75413
# Epoch 176/200
# 29/29 [==============================] - 3s 103ms/step - loss: 0.6661 - accuracy: 0.0285 - val_loss: 1.0005 - val_accuracy: 0.0277
#
# Epoch 00176: val_loss did not improve from 0.75413
# Epoch 177/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6659 - accuracy: 0.0285 - val_loss: 1.0012 - val_accuracy: 0.0277
#
# Epoch 00177: val_loss did not improve from 0.75413
# Epoch 178/200
# 29/29 [==============================] - 3s 106ms/step - loss: 0.6658 - accuracy: 0.0284 - val_loss: 1.0082 - val_accuracy: 0.0277
#
# Epoch 00178: val_loss did not improve from 0.75413
# Epoch 179/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6651 - accuracy: 0.0286 - val_loss: 1.0062 - val_accuracy: 0.0277
#
# Epoch 00179: val_loss did not improve from 0.75413
# Epoch 180/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6645 - accuracy: 0.0285 - val_loss: 0.9989 - val_accuracy: 0.0278
#
# Epoch 00180: val_loss did not improve from 0.75413
# Epoch 181/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6650 - accuracy: 0.0285 - val_loss: 1.0080 - val_accuracy: 0.0278
#
# Epoch 00181: val_loss did not improve from 0.75413
# Epoch 182/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6641 - accuracy: 0.0285 - val_loss: 1.0042 - val_accuracy: 0.0277
#
# Epoch 00182: val_loss did not improve from 0.75413
# Epoch 183/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6637 - accuracy: 0.0286 - val_loss: 0.9985 - val_accuracy: 0.0278
#
# Epoch 00183: val_loss did not improve from 0.75413
# Epoch 184/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6636 - accuracy: 0.0284 - val_loss: 1.0094 - val_accuracy: 0.0276
#
# Epoch 00184: val_loss did not improve from 0.75413
# Epoch 185/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6632 - accuracy: 0.0285 - val_loss: 0.9962 - val_accuracy: 0.0277
#
# Epoch 00185: val_loss did not improve from 0.75413
# Epoch 186/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6631 - accuracy: 0.0284 - val_loss: 1.0116 - val_accuracy: 0.0278
#
# Epoch 00186: val_loss did not improve from 0.75413
# Epoch 187/200
# 29/29 [==============================] - 3s 105ms/step - loss: 0.6630 - accuracy: 0.0285 - val_loss: 1.0129 - val_accuracy: 0.0277
#
# Epoch 00187: val_loss did not improve from 0.75413
# Epoch 188/200
# 29/29 [==============================] - 3s 111ms/step - loss: 0.6631 - accuracy: 0.0285 - val_loss: 1.0177 - val_accuracy: 0.0277
#
# Epoch 00188: val_loss did not improve from 0.75413
# Epoch 189/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.6623 - accuracy: 0.0286 - val_loss: 1.0172 - val_accuracy: 0.0275
#
# Epoch 00189: val_loss did not improve from 0.75413
# Epoch 190/200
# 29/29 [==============================] - 3s 110ms/step - loss: 0.6627 - accuracy: 0.0284 - val_loss: 1.0106 - val_accuracy: 0.0277
#
# Epoch 00190: val_loss did not improve from 0.75413
# Epoch 191/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6615 - accuracy: 0.0285 - val_loss: 1.0075 - val_accuracy: 0.0277
#
# Epoch 00191: val_loss did not improve from 0.75413
# Epoch 192/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6621 - accuracy: 0.0285 - val_loss: 1.0150 - val_accuracy: 0.0278
#
# Epoch 00192: val_loss did not improve from 0.75413
# Epoch 193/200
# 29/29 [==============================] - 3s 111ms/step - loss: 0.6616 - accuracy: 0.0284 - val_loss: 1.0231 - val_accuracy: 0.0276
#
# Epoch 00193: val_loss did not improve from 0.75413
# Epoch 194/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6613 - accuracy: 0.0285 - val_loss: 1.0066 - val_accuracy: 0.0277
#
# Epoch 00194: val_loss did not improve from 0.75413
# Epoch 195/200
# 29/29 [==============================] - 3s 113ms/step - loss: 0.6614 - accuracy: 0.0284 - val_loss: 1.0188 - val_accuracy: 0.0278
#
# Epoch 00195: val_loss did not improve from 0.75413
# Epoch 196/200
# 29/29 [==============================] - 3s 108ms/step - loss: 0.6609 - accuracy: 0.0285 - val_loss: 1.0164 - val_accuracy: 0.0278
#
# Epoch 00196: val_loss did not improve from 0.75413
# Epoch 197/200
# 29/29 [==============================] - 3s 104ms/step - loss: 0.6604 - accuracy: 0.0285 - val_loss: 1.0042 - val_accuracy: 0.0277
#
# Epoch 00197: val_loss did not improve from 0.75413
# Epoch 198/200
# 29/29 [==============================] - 3s 107ms/step - loss: 0.6607 - accuracy: 0.0284 - val_loss: 1.0231 - val_accuracy: 0.0276
#
# Epoch 00198: val_loss did not improve from 0.75413
# Epoch 199/200
# 29/29 [==============================] - 3s 109ms/step - loss: 0.6597 - accuracy: 0.0284 - val_loss: 1.0078 - val_accuracy: 0.0277
#
# Epoch 00199: val_loss did not improve from 0.75413
# Epoch 200/200
# 29/29 [==============================] - 3s 112ms/step - loss: 0.6601 - accuracy: 0.0285 - val_loss: 1.0218 - val_accuracy: 0.0277
#
# Epoch 00200: val_loss did not improve from 0.75413

# %% [markdown]
# ## 6. Test the model

# %%
def reply(paragraph, question):
    input_paragraph_seq = []
    input_question_seq = []
    input_paragraph_wid_list = []
    input_question_wid_list = []
    input_paragraph_text = paragraph.lower()
    input_question_text = question.lower()
    for word in nltk.word_tokenize(input_paragraph_text):
        if not in_white_list(word):
            continue
        idx = 1  # default [UNK]
        if word in input_paragraph_word2idx:
            idx = input_paragraph_word2idx[word]
        input_paragraph_wid_list.append(idx)
    for word in nltk.word_tokenize(input_question_text):
        if not in_white_list(word):
            continue
            idx = 1  # default [UNK]
        if word in input_question_word2idx:
            idx = input_question_word2idx[word]
        input_question_wid_list.append(idx)
    input_paragraph_seq.append(input_paragraph_wid_list)
    input_question_seq.append(input_question_wid_list)

    input_paragraph_seq = pad_sequences(input_paragraph_seq, input_paragraph_max_seq_length)
    input_question_seq = pad_sequences(input_question_seq, input_question_max_seq_length)
    states_value = encoder_model.predict([input_paragraph_seq, input_question_seq])

    target_seq = np.zeros((1, 1, num_target_tokens))
    target_seq[0, 0, target_word2idx['START']] = 1
    target_text = ''
    target_text_len = 0
    terminated = False
    while not terminated:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sample_token_idx = np.argmax(output_tokens[0, -1, :])
        sample_word = target_idx2word[sample_token_idx]
        target_text_len += 1

        if sample_word != 'START' and sample_word != 'END':
            target_text += ' ' + sample_word

        if sample_word == 'END' or target_text_len >= target_max_seq_length:
            terminated = True

        target_seq = np.zeros((1, 1, num_target_tokens))
        target_seq[0, 0, sample_token_idx] = 1

        states_value = [h, c]
    return target_text.strip()

# %%
for i in range(20):
    index = i * 10
    paragraph, question, actual_answer = data[index]
    predicted_answer = reply(paragraph, question)
    print('context: ', paragraph)
    print('question: ', question)
    print({'guessed_answer': predicted_answer, 'actual_answer': actual_answer})
    print("\n")
# Out:
# context:  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# question:  When did Beyonce start becoming popular?
# {'guessed_answer': '', 'actual_answer': 'in the late 1990s'}
#
#
# context:  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# question:  What was the first album Beyoncé released as a solo artist?
# {'guessed_answer': '7/8', 'actual_answer': 'Dangerously in Love'}
#
#
# context:  Frédéric François Chopin (/ˈʃoʊpæn/; French pronunciation: ​[fʁe.de.ʁik fʁɑ̃.swa ʃɔ.pɛ̃]; 22 February or 1 March 1810 – 17 October 1849), born Fryderyk Franciszek Chopin,[n 1] was a Polish and French (by citizenship and birth of father) composer and a virtuoso pianist of the Romantic era, who wrote primarily for the solo piano. He gained and has maintained renown worldwide as one of the leading musicians of his era, whose "poetic genius was based on a professional technique that was without equal in his generation." Chopin was born in what was then the Duchy of Warsaw, and grew up in Warsaw, which after 1815 became part of Congress Poland. A child prodigy, he completed his musical education and composed his earlier works in Warsaw before leaving Poland at the age of 20, less than a month before the outbreak of the November 1830 Uprising.
# question:  What year was Chopin born?
# {'guessed_answer': 'recognition', 'actual_answer': '1810'}
#
#
# context:  Frédéric François Chopin (/ˈʃoʊpæn/; French pronunciation: ​[fʁe.de.ʁik fʁɑ̃.swa ʃɔ.pɛ̃]; 22 February or 1 March 1810 – 17 October 1849), born Fryderyk Franciszek Chopin,[n 1] was a Polish and French (by citizenship and birth of father) composer and a virtuoso pianist of the Romantic era, who wrote primarily for the solo piano. He gained and has maintained renown worldwide as one of the leading musicians of his era, whose "poetic genius was based on a professional technique that was without equal in his generation." Chopin was born in what was then the Duchy of Warsaw, and grew up in Warsaw, which after 1815 became part of Congress Poland. A child prodigy, he completed his musical education and composed his earlier works in Warsaw before leaving Poland at the age of 20, less than a month before the outbreak of the November 1830 Uprising.
# question:  In what city was Chopin born and raised?
# {'guessed_answer': 'three', 'actual_answer': 'Warsaw'}
#
#
# context:  The iPod is a line of portable media players and multi-purpose pocket computers designed and marketed by Apple Inc. The first line was released on October 23, 2001, about 8½ months after iTunes (Macintosh version) was released. The most recent iPod redesigns were announced on July 15, 2015. There are three current versions of the iPod: the ultra-compact iPod Shuffle, the compact iPod Nano and the touchscreen iPod Touch.
# question:  In what year was the first iPod released?
# {'guessed_answer': 'a', 'actual_answer': '2001'}
#
#
# context:  The Legend of Zelda: Twilight Princess (Japanese: ゼルダの伝説 トワイライトプリンセス, Hepburn: Zeruda no Densetsu: Towairaito Purinsesu?) is an action-adventure game developed and published by Nintendo for the GameCube and Wii home video game consoles. It is the thirteenth installment in the The Legend of Zelda series. Originally planned for release on the GameCube in November 2005, Twilight Princess was delayed by Nintendo to allow its developers to refine the game, add more content, and port it to the Wii. The Wii version was released alongside the console in North America in November 2006, and in Japan, Europe, and Australia the following month. The GameCube version was released worldwide in December 2006.[b]
# question:  What year was the Legend of Zelda:Twilight Princess originally planned for release?
# {'guessed_answer': 'a', 'actual_answer': '2005'}
#
#
# context:  Spectre (2015) is the twenty-fourth James Bond film produced by Eon Productions. It features Daniel Craig in his fourth performance as James Bond, and Christoph Waltz as Ernst Stavro Blofeld, with the film marking the character's re-introduction into the series. It was directed by Sam Mendes as his second James Bond film following Skyfall, and was written by John Logan, Neal Purvis, Robert Wade and Jez Butterworth. It is distributed by Metro-Goldwyn-Mayer and Columbia Pictures. With a budget around $245 million, it is the most expensive Bond film and one of the most expensive films ever made.
# question:  Which two movie studios distributed the James Bond film Spectre?
# {'guessed_answer': 'romantic', 'actual_answer': 'Metro-Goldwyn-Mayer and Columbia Pictures'}
#
#
# context:  New York—often called New York City or the City of New York to distinguish it from the State of New York, of which it is a part—is the most populous city in the United States and the center of the New York metropolitan area, the premier gateway for legal immigration to the United States and one of the most populous urban agglomerations in the world. A global power city, New York exerts a significant impact upon commerce, finance, media, art, fashion, research, technology, education, and entertainment, its fast pace defining the term New York minute. Home to the headquarters of the United Nations, New York is an important center for international diplomacy and has been described as the cultural and financial capital of the world.
# question:  What city in the United States has the highest population?
# {'guessed_answer': 'john', 'actual_answer': 'New York'}
#
#
# context:  To Kill a Mockingbird is a novel by Harper Lee published in 1960. It was immediately successful, winning the Pulitzer Prize, and has become a classic of modern American literature. The plot and characters are loosely based on the author's observations of her family and neighbors, as well as on an event that occurred near her hometown in 1936, when she was 10 years old.
# question:  What year was To Kill a Mockingbird first published?
# {'guessed_answer': 'ukraine', 'actual_answer': '1960'}
#
#
# context:  Buddhism /ˈbudɪzəm/ is a nontheistic religion[note 1] or philosophy (Sanskrit: धर्म dharma; Pali: धम्म dhamma) that encompasses a variety of traditions, beliefs and spiritual practices largely based on teachings attributed to Gautama Buddha, commonly known as the Buddha ("the awakened one"). According to Buddhist tradition, the Buddha lived and taught in the eastern part of the Indian subcontinent, present-day Nepal sometime between the 6th and 4th centuries BCE.[note 1] He is recognized by Buddhists as an awakened or enlightened teacher who shared his insights to help sentient beings end their suffering through the elimination of ignorance and craving. Buddhists believe that this is accomplished through the direct understanding and perception of dependent origination and the Four Noble Truths.
# question:  What type of religion is Buddhism?
# {'guessed_answer': 'recognition', 'actual_answer': 'nontheistic'}
#
#
# context:  Buddhism /ˈbudɪzəm/ is a nontheistic religion[note 1] or philosophy (Sanskrit: धर्म dharma; Pali: धम्म dhamma) that encompasses a variety of traditions, beliefs and spiritual practices largely based on teachings attributed to Gautama Buddha, commonly known as the Buddha ("the awakened one"). According to Buddhist tradition, the Buddha lived and taught in the eastern part of the Indian subcontinent, present-day Nepal sometime between the 6th and 4th centuries BCE.[note 1] He is recognized by Buddhists as an awakened or enlightened teacher who shared his insights to help sentient beings end their suffering through the elimination of ignorance and craving. Buddhists believe that this is accomplished through the direct understanding and perception of dependent origination and the Four Noble Truths.
# question:  Where was Buddha thought to live?
# {'guessed_answer': 'a', 'actual_answer': 'Nepal'}
#
#
# context:  American Idol is an American singing competition series created by Simon Fuller and produced by 19 Entertainment, and is distributed by FremantleMedia North America. It began airing on Fox on June 11, 2002, as an addition to the Idols format based on the British series Pop Idol and has since become one of the most successful shows in the history of American television. The concept of the series is to find new solo recording artists, with the winner being determined by the viewers in America. Winners chosen by viewers through telephone, Internet, and SMS text voting were Kelly Clarkson, Ruben Studdard, Fantasia Barrino, Carrie Underwood, Taylor Hicks, Jordin Sparks, David Cook, Kris Allen, Lee DeWyze, Scotty McCreery, Phillip Phillips, Candice Glover, Caleb Johnson, and Nick Fradiani.
# question:  What television network does American Idol air on?
# {'guessed_answer': 'san', 'actual_answer': 'Fox'}
#
#
# context:  The domestic dog (Canis lupus familiaris or Canis familiaris) is a domesticated canid which has been selectively bred for millennia for various behaviors, sensory capabilities, and physical attributes.
# question:  Along with various behaviors and physical attributes, what were domestic dogs bred for?
# {'guessed_answer': 'nontheistic', 'actual_answer': 'sensory capabilities'}
#
#
# context:  In modern molecular biology and genetics, the genome is the genetic material of an organism. It consists of DNA (or RNA in RNA viruses). The genome includes both the genes and the non-coding sequences of the DNA/RNA.
# question:  What is the content of the human genome?
# {'guessed_answer': 'a', 'actual_answer': 'DNA'}
#
#
# context:  The Republic of the Congo (French: République du Congo), also known as Congo, Congo Republic, West Congo[citation needed], or Congo-Brazzaville, is a country located in Central Africa. It is bordered by five countries: Gabon to the west; Cameroon to the northwest; the Central African Republic to the northeast; the Democratic Republic of the Congo to the east and south; and the Angolan exclave of Cabinda to the southwest.
# question:  Which country lies on Congo's northwest border?
# {'guessed_answer': '7/8', 'actual_answer': 'Cameroon'}
#
#
# context:  The Wayback Machine is a digital archive of the World Wide Web and other information on the Internet created by the Internet Archive, a nonprofit organization, based in San Francisco, California, United States. It was set up by Brewster Kahle and Bruce Gilliat, and is maintained with content from Alexa Internet. The service enables users to see archived versions of web pages across time, which the archive calls a "three dimensional index."
# question:  What is the term used by Internet Archive to describe the Wayback Machine?
# {'guessed_answer': '1837', 'actual_answer': 'three dimensional index'}
#
#
# context:  The Canadian Armed Forces (CAF; French: Forces armées canadiennes, FAC), or Canadian Forces (CF) (French: les Forces canadiennes, FC), is the unified armed force of Canada, as constituted by the National Defence Act, which states: "The Canadian Forces are the armed forces of Her Majesty raised by Canada and consist of one Service called the Canadian Armed Forces."
# question:  What does CF stand for in this context?
# {'guessed_answer': '', 'actual_answer': 'Forces canadiennes'}
#
#
# context:  Lighting or illumination is the deliberate use of light to achieve a practical or aesthetic effect. Lighting includes the use of both artificial light sources like lamps and light fixtures, as well as natural illumination by capturing daylight. Daylighting (using windows, skylights, or light shelves) is sometimes used as the main source of light during daytime in buildings. This can save energy in place of using artificial lighting, which represents a major component of energy consumption in buildings. Proper lighting can enhance task performance, improve the appearance of an area, or have positive psychological effects on occupants.
# question:  Using natural illumination instead of artificial light sources help with what?
# {'guessed_answer': 'a', 'actual_answer': 'energy consumption'}
#
#
# context:  Separation of powers is a political doctrine originating in the writings of Montesquieu in The Spirit of the Laws where he urged for a constitutional government with three separate branches of government. Each of the three branches would have defined abilities to check the powers of the other branches. This idea was called separation of powers. This philosophy heavily influenced the writing of the United States Constitution, according to which the Legislative, Executive, and Judicial branches of the United States government are kept distinct in order to prevent abuse of power. This United States form of separation of powers is associated with a system of checks and balances.
# question:  What document was greatly informed by the idea of separation of powers?
# {'guessed_answer': 'a', 'actual_answer': 'United States Constitution'}
#
#
# context:  The Human Development Index (HDI) is a composite statistic of life expectancy, education, and income per capita indicators, which are used to rank countries into four tiers of human development. A country scores higher HDI when the life expectancy at birth is longer, the education period is longer, and the income per capita is higher. The HDI was developed by the Pakistani economist Mahbub ul Haq, often framed in terms of whether people are able to "be" and "do" desirable things in their life, and was published by the United Nations Development Programme.
# question:  Does a high ranking on the HDI indicate shorter or longer life expectancy?
# {'guessed_answer': 'romantic', 'actual_answer': 'longer'}
