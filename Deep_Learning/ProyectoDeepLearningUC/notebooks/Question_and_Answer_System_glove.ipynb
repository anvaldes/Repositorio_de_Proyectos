# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Question answering system
#
# Question answering is a computer science discipline within the fields of information retrieval and natural language processing, which is concerned with building systems that automatically answer questions posed by humans in a natural language.

# %% [markdown]
# ![qa.png](qa.png)

# %% [markdown]
# The objective here is to build a Question answering system using the seq2seq approach.

# %% [markdown]
# ### SQuAD Dataset
#
# Stanford Question Answering Dataset (SQuAD) is a reading comprehension dataset, consisting of questions posed by crowdworkers on a set of Wikipedia articles, where the answer to every question is a segment of text, or span, from the corresponding reading passage, or the question might be unanswerable.
#
# We can download the dataset from [here](https://rajpurkar.github.io/SQuAD-explorer/)

# %%
# !wget "https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json"
# !wget "https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json"
# Out:
# --2021-07-21 01:32:44--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.111.153, 185.199.109.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘train-v2.0.json.1’
#
# train-v2.0.json.1   100%[===================>]  40.17M  --.-KB/s    in 0.1s
#
# 2021-07-21 01:32:46 (284 MB/s) - ‘train-v2.0.json.1’ saved [42123633/42123633]
#
# --2021-07-21 01:32:46--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.111.153, 185.199.109.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4370528 (4.2M) [application/json]
# Saving to: ‘dev-v2.0.json.1’
#
# dev-v2.0.json.1     100%[===================>]   4.17M  --.-KB/s    in 0.06s
#
# 2021-07-21 01:32:46 (66.1 MB/s) - ‘dev-v2.0.json.1’ saved [4370528/4370528]

# %%
% cd content
# Out:
# [Errno 2] No such file or directory: 'content'
# /content

# %%
# Importing packages
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

import os
from collections import Counter
from sklearn.model_selection import train_test_split

# import tensorflow as tf
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# session = tf.Session(config=config)

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Permute, dot, add, concatenate
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, Activation,RepeatVector
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import History
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## 1. Getting Data

# %%
with open("train-v2.0.json",mode="rt",encoding="utf-8") as file:
    qa_data = json.load(file)

# %%
#qa_data["data"][0]['paragraphs'][0]["qas"][0]["question"]
#qa_data["data"][0]['paragraphs'][0]["qas"][0]["answers"]

# %% [markdown]
# ## 2. Pre-processing

# %%
lookup = 'abcdefghijklmnopqrstuvwxyz1234567890?.,'
# check for valid characters
def in_white_list(_word):
    valid_word = False
    for char in _word:
        if char in lookup:
            valid_word = True
            break

    if valid_word is False:
        return False

    return True

# %%
# extract paragraphs,question and answers from SQuAD_data
def get_SQuAD_data(qa_data,max_data_count,max_context_seq_length,max_question_seq_length,max_target_seq_length):
    data = list()
    for instance in qa_data['data']:
        for paragraph in instance['paragraphs']:
            context = paragraph['context']
            context_wid_list = [w.lower() for w in nltk.word_tokenize(context) if in_white_list(w)]
            # if len(context_wid_list) > max_context_seq_length:
            #     continue
            qas = paragraph['qas']
            for qas_instance in qas:
                question = qas_instance['question']
                question_wid_list = [w.lower() for w in nltk.word_tokenize(question) if in_white_list(w)]
                # if len(question_wid_list) > max_question_seq_length:
                #     continue
                answers = qas_instance['answers']
                for answer in answers:
                    ans = answer['text']
                    answer_wid_list = [w.lower() for w in nltk.word_tokenize(ans) if in_white_list(w)]
                    # if len(answer_wid_list) > max_target_seq_length:
                    #     continue
                    # if len(data) < max_data_count:
                    #     data.append((context, question, ans))
                    data.append((context, question, ans))

            # if len(data) >= max_data_count:
            #     break

            # break
    return data

# %%
max_data_count = 10000
max_context_seq_length = 300
max_question_seq_length = 60
max_target_seq_length = 50
data = get_SQuAD_data(qa_data,max_data_count,max_context_seq_length,max_question_seq_length,max_target_seq_length)
print("Total Q&A data size",len(data))
# Out:
# Total Q&A data size 86821

# %% [markdown]
# ## 3. Feature Extraction

# %%
# Get Glove word embeddings
! wget -O glove.zip http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2021-07-21 01:33:35--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2021-07-21 01:33:35--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2021-07-21 01:33:35--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.zip’
#
# glove.zip           100%[===================>] 822.24M  5.01MB/s    in 2m 42s
#
# 2021-07-21 01:36:17 (5.09 MB/s) - ‘glove.zip’ saved [862182613/862182613]

# %%
from zipfile import ZipFile
with ZipFile('glove.zip', 'r') as z:
    z.extractall("glove")

# %%
# Load Glove vectors
embedding_size = 300
embeddings_index = {} # empty dictionary
f = open(os.path.join("glove/", 'glove.6B.'+str(embedding_size)+'d.txt'), encoding="utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
# get glove embedding
def encode_word(word):
    if word in embeddings_index:
        return embeddings_index[word]
    else:
        return np.zeros(shape=embedding_size)

# %%
max_target_vocab_size = 5000
input_data_samples = []
output_data_samples = []

input_paragraph_max_seq_length = 0
input_question_max_seq_length = 0
target_max_seq_length = 0

temp_emb = np.zeros(shape=embedding_size)
target_counter = Counter()

input_data_samples = []
output_data_samples = []

# %%
# iterate over each paragraph, question and answer
for sample in data:
    paragraph, question, answer = sample
    paragraph_word_list = [w.lower() for w in nltk.word_tokenize(paragraph) if in_white_list(w)]
    question_word_list = [w.lower() for w in nltk.word_tokenize(question) if in_white_list(w)]
    answer_word_list = [w.lower() for w in nltk.word_tokenize(answer) if in_white_list(w)]

    output_data = ['START'] + answer_word_list + ['END']

    input_data_samples.append([paragraph_word_list, question_word_list])
    output_data_samples.append(output_data)

    for w in output_data:
        target_counter[w] += 1

    input_paragraph_max_seq_length = max(input_paragraph_max_seq_length, len(paragraph_word_list))
    input_question_max_seq_length = max(input_question_max_seq_length, len(question_word_list))
    target_max_seq_length = max(target_max_seq_length, len(output_data))

# %%
# create dictionary of output sequence
# Mapping from word to index 
target_word2idx = dict()
for idx, word in enumerate(target_counter.most_common(max_target_vocab_size)):
    target_word2idx[word[0]] = idx + 1

target_word2idx['UNK'] = 0
target_idx2word = dict([(idx, word) for word, idx in target_word2idx.items()])
num_target_tokens = len(target_idx2word)

# %% [markdown]
# ### Create sequences

# %%
input_encoded_data_samples = []
target_encoded_data_samples = []
# iterate over each text sample from paragraphs, questions and answers
for input_data, output_data in zip(input_data_samples, output_data_samples):
    input_paragraph_encoded_data = []
    input_question_encoded_data = []
    target_encoded_data = []
    input_paragraph_data, input_question_data = input_data
    for word in input_question_data:
        if word in embeddings_index:
            input_question_encoded_data.append(embeddings_index[word])
        else:
            input_question_encoded_data.append(temp_emb)
    for word in input_paragraph_data:
        if word in embeddings_index:
            input_paragraph_encoded_data.append(embeddings_index[word])
        else:
            input_paragraph_encoded_data.append(temp_emb)
    for word in output_data:
        if word in target_word2idx:
            target_encoded_data.append(target_word2idx[word])
        else:
            target_encoded_data.append(0)
    input_encoded_data_samples.append([input_paragraph_encoded_data, input_question_encoded_data])
    target_encoded_data_samples.append(target_encoded_data)

# %%
batch_size = 64
epochs = 200
test_size = 0.2
random_state = 42

# %%
# get train and test samples
x_train, x_test, y_train, y_test = train_test_split(input_encoded_data_samples, target_encoded_data_samples, test_size=test_size,random_state=random_state)

# %%
# train and test generator
def generate_batch(input_paragraph_max_seq_length,input_question_max_seq_length,target_max_seq_length,num_target_tokens, input_data, output_data, batch_size):
    num_batches = len(input_data) // batch_size
    while True:
        for batchIdx in range(0, num_batches):
            start = batchIdx * batch_size
            end = (batchIdx + 1) * batch_size
            encoder_input_paragraph_data_batch = []
            encoder_input_question_data_batch = []
            for input_paragraph_data, input_question_data in input_data[start:end]:
                encoder_input_paragraph_data_batch.append(input_paragraph_data)
                encoder_input_question_data_batch.append(input_question_data)
            encoder_input_paragraph_data_batch = pad_sequences(encoder_input_paragraph_data_batch,
                                                               input_paragraph_max_seq_length)
            encoder_input_question_data_batch = pad_sequences(encoder_input_question_data_batch,
                                                              input_question_max_seq_length)
            decoder_target_data_batch = np.zeros(shape=(batch_size, target_max_seq_length, num_target_tokens))
            decoder_input_data_batch = np.zeros(shape=(batch_size, target_max_seq_length, num_target_tokens))
            for lineIdx, target_wid_list in enumerate(output_data[start:end]):
                for idx, wid in enumerate(target_wid_list):
                    if wid == 0:  # UNKNOWN
                        continue
                    decoder_input_data_batch[lineIdx, idx, wid] = 1
                    if idx > 0:
                        decoder_target_data_batch[lineIdx, idx - 1, wid] = 1
            yield [encoder_input_paragraph_data_batch, encoder_input_question_data_batch,
                   decoder_input_data_batch], decoder_target_data_batch

# %%
# get train and test generators
train_gen = generate_batch(input_paragraph_max_seq_length,input_question_max_seq_length,target_max_seq_length,num_target_tokens, x_train, y_train, batch_size)
test_gen = generate_batch(input_paragraph_max_seq_length,input_question_max_seq_length,target_max_seq_length,num_target_tokens, x_test, y_test, batch_size)

# %%
# get train and test batch size
train_num_batches = len(x_train) // batch_size
test_num_batches = len(x_test) // batch_size

# %% [markdown]
# ## 4. Build the model

# %% [markdown]
# ![encode_decode.jpeg](encode_decode.jpeg)

# %%
def create_model(embedding_size,max_encoder_paragraph_seq_length,num_decoder_tokens):
    hidden_units = 256

    context_inputs = Input(shape=(None, embedding_size), name='context_inputs')
    encoded_context = Dropout(0.3)(context_inputs)

    question_inputs = Input(shape=(None, embedding_size), name='question_inputs')
    encoded_question = Dropout(0.3)(question_inputs)
    encoded_question = LSTM(units=embedding_size, name='question_lstm')(encoded_question)
    encoded_question = RepeatVector(max_encoder_paragraph_seq_length)(encoded_question)

    merged = add([encoded_context, encoded_question])
    encoder_outputs, encoder_state_h, encoder_state_c = LSTM(units=hidden_units,
                                                                 name='encoder_lstm', return_state=True)(merged)

    encoder_states = [encoder_state_h, encoder_state_c]

    decoder_inputs = Input(shape=(None, num_decoder_tokens), name='decoder_inputs')
    decoder_lstm = LSTM(units=hidden_units, return_state=True, return_sequences=True, name='decoder_lstm')
    decoder_outputs, decoder_state_h, decoder_state_c = decoder_lstm(decoder_inputs,
                                                                         initial_state=encoder_states)
    decoder_dense = Dense(units=num_decoder_tokens, activation='softmax', name='decoder_dense')
    decoder_outputs = decoder_dense(decoder_outputs)

    model = Model([context_inputs, question_inputs, decoder_inputs], decoder_outputs)

    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

    encoder_model = Model([context_inputs, question_inputs], encoder_states)

    decoder_state_inputs = [Input(shape=(hidden_units,)), Input(shape=(hidden_units,))]
    decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_state_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = Model([decoder_inputs] + decoder_state_inputs, [decoder_outputs] + decoder_states)
    return model, encoder_model, decoder_model

# %%
# build model
model, encoder_model, decoder_model = create_model(embedding_size,input_paragraph_max_seq_length,num_target_tokens)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# question_inputs (InputLayer)    [(None, None, 300)]  0
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 300)    0           question_inputs[0][0]
# __________________________________________________________________________________________________
# context_inputs (InputLayer)     [(None, None, 300)]  0
# __________________________________________________________________________________________________
# question_lstm (LSTM)            (None, 300)          721200      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 300)    0           context_inputs[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 673, 300)     0           question_lstm[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 673, 300)     0           dropout[0][0]
#                                                                  repeat_vector[0][0]
# __________________________________________________________________________________________________
# decoder_inputs (InputLayer)     [(None, None, 5001)] 0
# __________________________________________________________________________________________________
# encoder_lstm (LSTM)             [(None, 256), (None, 570368      add[0][0]
# __________________________________________________________________________________________________
# decoder_lstm (LSTM)             [(None, None, 256),  5384192     decoder_inputs[0][0]
#                                                                  encoder_lstm[0][1]
#                                                                  encoder_lstm[0][2]
# __________________________________________________________________________________________________
# decoder_dense (Dense)           (None, None, 5001)   1285257     decoder_lstm[0][0]
# ==================================================================================================
# Total params: 7,961,017
# Trainable params: 7,961,017
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_glove.png', show_shapes=True)

# %%
# Defining a helper function to save the model after each epoch 
# in which the loss decreases
drivepath  = '/content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/'
filepath   = drivepath + 'model_QandA.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
# Defining a helper function to reduce the learning rate each time 
# the learning plateaus 
reduce_alpha = ReduceLROnPlateau(monitor ='val_loss', factor = 0.2, patience = 1, min_lr = 0.001)
# stop traning if there increase in loss
# es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)
callbacks = [checkpoint, reduce_alpha]

# %% [markdown]
# ## 5. Train the model

# %%
history = model.fit_generator(generator=train_gen, steps_per_epoch=train_num_batches,
                                           epochs=epochs,
                                           verbose=1, validation_data=test_gen, validation_steps=test_num_batches,
                                           callbacks=callbacks)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/200
# 1085/1085 [==============================] - 190s 171ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4592 - val_accuracy: 0.0208
#
# Epoch 00001: val_loss improved from inf to 0.45919, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# 1085/1085 [==============================] - 196s 181ms/step - loss: 0.4579 - accuracy: 0.0208 - val_loss: 0.4592 - val_accuracy: 0.0208
#
# Epoch 00002: val_loss did not improve from 0.45919
# Epoch 3/200
# 1085/1085 [==============================] - 190s 175ms/step - loss: 0.4578 - accuracy: 0.0208 - val_loss: 0.4592 - val_accuracy: 0.0208
#
# Epoch 00003: val_loss improved from 0.45919 to 0.45915, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 4/200
# 1085/1085 [==============================] - 181s 167ms/step - loss: 0.4578 - accuracy: 0.0208 - val_loss: 0.4591 - val_accuracy: 0.0208
#
# Epoch 00004: val_loss improved from 0.45915 to 0.45909, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 5/200
# 1085/1085 [==============================] - 189s 174ms/step - loss: 0.4578 - accuracy: 0.0208 - val_loss: 0.4590 - val_accuracy: 0.0208
#
# Epoch 00005: val_loss improved from 0.45909 to 0.45900, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 6/200
# 1085/1085 [==============================] - 184s 170ms/step - loss: 0.4578 - accuracy: 0.0208 - val_loss: 0.4595 - val_accuracy: 0.0208
#
# Epoch 00006: val_loss did not improve from 0.45900
# Epoch 7/200
# 1085/1085 [==============================] - 186s 172ms/step - loss: 0.4577 - accuracy: 0.0208 - val_loss: 0.4591 - val_accuracy: 0.0208
#
# Epoch 00007: val_loss did not improve from 0.45900
# Epoch 8/200
# 1085/1085 [==============================] - 190s 175ms/step - loss: 0.4577 - accuracy: 0.0208 - val_loss: 0.4590 - val_accuracy: 0.0208
#
# Epoch 00008: val_loss improved from 0.45900 to 0.45897, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 9/200
# 1085/1085 [==============================] - 188s 173ms/step - loss: 0.4577 - accuracy: 0.0208 - val_loss: 0.4602 - val_accuracy: 0.0208
#
# Epoch 00009: val_loss did not improve from 0.45897
# Epoch 10/200
# 1085/1085 [==============================] - 183s 168ms/step - loss: 0.4577 - accuracy: 0.0208 - val_loss: 0.4592 - val_accuracy: 0.0208
#
# Epoch 00010: val_loss did not improve from 0.45897
# Epoch 11/200
# 1085/1085 [==============================] - 188s 173ms/step - loss: 0.4576 - accuracy: 0.0208 - val_loss: 0.4588 - val_accuracy: 0.0208
#
# Epoch 00011: val_loss improved from 0.45897 to 0.45876, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 12/200
# 1085/1085 [==============================] - 182s 168ms/step - loss: 0.4576 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00012: val_loss did not improve from 0.45876
# Epoch 13/200
# 1085/1085 [==============================] - 184s 169ms/step - loss: 0.4576 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00013: val_loss did not improve from 0.45876
# Epoch 14/200
# 1085/1085 [==============================] - 188s 173ms/step - loss: 0.4576 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00014: val_loss did not improve from 0.45876
# Epoch 15/200
# 1085/1085 [==============================] - 192s 177ms/step - loss: 0.4575 - accuracy: 0.0208 - val_loss: 0.4590 - val_accuracy: 0.0208
#
# Epoch 00015: val_loss did not improve from 0.45876
# Epoch 16/200
# 1085/1085 [==============================] - 179s 165ms/step - loss: 0.4575 - accuracy: 0.0208 - val_loss: 0.4594 - val_accuracy: 0.0208
#
# Epoch 00016: val_loss did not improve from 0.45876
# Epoch 17/200
# 1085/1085 [==============================] - 181s 167ms/step - loss: 0.4575 - accuracy: 0.0208 - val_loss: 0.4587 - val_accuracy: 0.0208
#
# Epoch 00017: val_loss improved from 0.45876 to 0.45873, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 18/200
# 1085/1085 [==============================] - 178s 165ms/step - loss: 0.4574 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00018: val_loss improved from 0.45873 to 0.45863, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 19/200
# 1085/1085 [==============================] - 182s 168ms/step - loss: 0.4574 - accuracy: 0.0208 - val_loss: 0.4592 - val_accuracy: 0.0208
#
# Epoch 00019: val_loss did not improve from 0.45863
# Epoch 20/200
# 1085/1085 [==============================] - 183s 169ms/step - loss: 0.4574 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00020: val_loss did not improve from 0.45863
# Epoch 21/200
# 1085/1085 [==============================] - 177s 164ms/step - loss: 0.4574 - accuracy: 0.0208 - val_loss: 0.4601 - val_accuracy: 0.0208
#
# Epoch 00021: val_loss did not improve from 0.45863
# Epoch 22/200
# 1085/1085 [==============================] - 176s 163ms/step - loss: 0.4574 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00022: val_loss improved from 0.45863 to 0.45857, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 23/200
# 1085/1085 [==============================] - 182s 168ms/step - loss: 0.4573 - accuracy: 0.0208 - val_loss: 0.4594 - val_accuracy: 0.0208
#
# Epoch 00023: val_loss did not improve from 0.45857
# Epoch 24/200
# 1085/1085 [==============================] - 176s 163ms/step - loss: 0.4573 - accuracy: 0.0208 - val_loss: 0.4596 - val_accuracy: 0.0208
#
# Epoch 00024: val_loss did not improve from 0.45857
# Epoch 25/200
# 1085/1085 [==============================] - 173s 160ms/step - loss: 0.4573 - accuracy: 0.0208 - val_loss: 0.4583 - val_accuracy: 0.0208
#
# Epoch 00025: val_loss improved from 0.45857 to 0.45832, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 26/200
# 1085/1085 [==============================] - 175s 161ms/step - loss: 0.4572 - accuracy: 0.0208 - val_loss: 0.4580 - val_accuracy: 0.0208
#
# Epoch 00026: val_loss improved from 0.45832 to 0.45802, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 27/200
# 1085/1085 [==============================] - 168s 155ms/step - loss: 0.4572 - accuracy: 0.0208 - val_loss: 0.4595 - val_accuracy: 0.0208
#
# Epoch 00027: val_loss did not improve from 0.45802
# Epoch 28/200
# 1085/1085 [==============================] - 173s 159ms/step - loss: 0.4572 - accuracy: 0.0208 - val_loss: 0.4591 - val_accuracy: 0.0208
#
# Epoch 00028: val_loss did not improve from 0.45802
# Epoch 29/200
# 1085/1085 [==============================] - 182s 168ms/step - loss: 0.4572 - accuracy: 0.0208 - val_loss: 0.4593 - val_accuracy: 0.0208
#
# Epoch 00029: val_loss did not improve from 0.45802
# Epoch 30/200
# 1085/1085 [==============================] - 176s 163ms/step - loss: 0.4572 - accuracy: 0.0208 - val_loss: 0.4593 - val_accuracy: 0.0208
#
# Epoch 00030: val_loss did not improve from 0.45802
# Epoch 31/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4571 - accuracy: 0.0208 - val_loss: 0.4583 - val_accuracy: 0.0208
#
# Epoch 00031: val_loss did not improve from 0.45802
# Epoch 32/200
# 1085/1085 [==============================] - 174s 160ms/step - loss: 0.4571 - accuracy: 0.0208 - val_loss: 0.4580 - val_accuracy: 0.0208
#
# Epoch 00032: val_loss improved from 0.45802 to 0.45802, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 33/200
# 1085/1085 [==============================] - 168s 155ms/step - loss: 0.4571 - accuracy: 0.0208 - val_loss: 0.4584 - val_accuracy: 0.0208
#
# Epoch 00033: val_loss did not improve from 0.45802
# Epoch 34/200
# 1085/1085 [==============================] - 170s 157ms/step - loss: 0.4570 - accuracy: 0.0208 - val_loss: 0.4592 - val_accuracy: 0.0208
#
# Epoch 00034: val_loss did not improve from 0.45802
# Epoch 35/200
# 1085/1085 [==============================] - 170s 156ms/step - loss: 0.4570 - accuracy: 0.0208 - val_loss: 0.4591 - val_accuracy: 0.0208
#
# Epoch 00035: val_loss did not improve from 0.45802
# Epoch 36/200
# 1085/1085 [==============================] - 170s 157ms/step - loss: 0.4570 - accuracy: 0.0208 - val_loss: 0.4591 - val_accuracy: 0.0208
#
# Epoch 00036: val_loss did not improve from 0.45802
# Epoch 37/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4570 - accuracy: 0.0208 - val_loss: 0.4590 - val_accuracy: 0.0208
#
# Epoch 00037: val_loss did not improve from 0.45802
# Epoch 38/200
# 1085/1085 [==============================] - 174s 160ms/step - loss: 0.4569 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00038: val_loss improved from 0.45802 to 0.45795, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 39/200
# 1085/1085 [==============================] - 174s 161ms/step - loss: 0.4569 - accuracy: 0.0208 - val_loss: 0.4580 - val_accuracy: 0.0208
#
# Epoch 00039: val_loss did not improve from 0.45795
# Epoch 40/200
# 1085/1085 [==============================] - 171s 158ms/step - loss: 0.4569 - accuracy: 0.0208 - val_loss: 0.4596 - val_accuracy: 0.0208
#
# Epoch 00040: val_loss did not improve from 0.45795
# Epoch 41/200
# 1085/1085 [==============================] - 179s 165ms/step - loss: 0.4569 - accuracy: 0.0208 - val_loss: 0.4585 - val_accuracy: 0.0208
#
# Epoch 00041: val_loss did not improve from 0.45795
# Epoch 42/200
# 1085/1085 [==============================] - 174s 161ms/step - loss: 0.4568 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00042: val_loss did not improve from 0.45795
# Epoch 43/200
# 1085/1085 [==============================] - 172s 158ms/step - loss: 0.4568 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00043: val_loss did not improve from 0.45795
# Epoch 44/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4568 - accuracy: 0.0208 - val_loss: 0.4590 - val_accuracy: 0.0208
#
# Epoch 00044: val_loss did not improve from 0.45795
# Epoch 45/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4568 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00045: val_loss did not improve from 0.45795
# Epoch 46/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4567 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00046: val_loss did not improve from 0.45795
# Epoch 47/200
# 1085/1085 [==============================] - 173s 159ms/step - loss: 0.4567 - accuracy: 0.0208 - val_loss: 0.4585 - val_accuracy: 0.0208
#
# Epoch 00047: val_loss did not improve from 0.45795
# Epoch 48/200
# 1085/1085 [==============================] - 177s 163ms/step - loss: 0.4567 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00048: val_loss improved from 0.45795 to 0.45794, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 49/200
# 1085/1085 [==============================] - 168s 155ms/step - loss: 0.4566 - accuracy: 0.0208 - val_loss: 0.4603 - val_accuracy: 0.0208
#
# Epoch 00049: val_loss did not improve from 0.45794
# Epoch 50/200
# 1085/1085 [==============================] - 176s 163ms/step - loss: 0.4566 - accuracy: 0.0208 - val_loss: 0.4591 - val_accuracy: 0.0208
#
# Epoch 00050: val_loss did not improve from 0.45794
# Epoch 51/200
# 1085/1085 [==============================] - 170s 156ms/step - loss: 0.4566 - accuracy: 0.0208 - val_loss: 0.4587 - val_accuracy: 0.0208
#
# Epoch 00051: val_loss did not improve from 0.45794
# Epoch 52/200
# 1085/1085 [==============================] - 172s 158ms/step - loss: 0.4566 - accuracy: 0.0208 - val_loss: 0.4584 - val_accuracy: 0.0208
#
# Epoch 00052: val_loss did not improve from 0.45794
# Epoch 53/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4565 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00053: val_loss did not improve from 0.45794
# Epoch 54/200
# 1085/1085 [==============================] - 171s 158ms/step - loss: 0.4565 - accuracy: 0.0208 - val_loss: 0.4582 - val_accuracy: 0.0208
#
# Epoch 00054: val_loss did not improve from 0.45794
# Epoch 55/200
# 1085/1085 [==============================] - 169s 155ms/step - loss: 0.4565 - accuracy: 0.0208 - val_loss: 0.4584 - val_accuracy: 0.0208
#
# Epoch 00055: val_loss did not improve from 0.45794
# Epoch 56/200
# 1085/1085 [==============================] - 170s 157ms/step - loss: 0.4565 - accuracy: 0.0208 - val_loss: 0.4588 - val_accuracy: 0.0208
#
# Epoch 00056: val_loss did not improve from 0.45794
# Epoch 57/200
# 1085/1085 [==============================] - 172s 158ms/step - loss: 0.4564 - accuracy: 0.0208 - val_loss: 0.4587 - val_accuracy: 0.0208
#
# Epoch 00057: val_loss did not improve from 0.45794
# Epoch 58/200
# 1085/1085 [==============================] - 172s 158ms/step - loss: 0.4564 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00058: val_loss did not improve from 0.45794
# Epoch 59/200
# 1085/1085 [==============================] - 168s 155ms/step - loss: 0.4564 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00059: val_loss did not improve from 0.45794
# Epoch 60/200
# 1085/1085 [==============================] - 165s 153ms/step - loss: 0.4563 - accuracy: 0.0208 - val_loss: 0.4578 - val_accuracy: 0.0208
#
# Epoch 00060: val_loss improved from 0.45794 to 0.45782, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 61/200
# 1085/1085 [==============================] - 169s 156ms/step - loss: 0.4563 - accuracy: 0.0208 - val_loss: 0.4573 - val_accuracy: 0.0208
#
# Epoch 00061: val_loss improved from 0.45782 to 0.45726, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 62/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4563 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00062: val_loss did not improve from 0.45726
# Epoch 63/200
# 1085/1085 [==============================] - 171s 158ms/step - loss: 0.4563 - accuracy: 0.0208 - val_loss: 0.4578 - val_accuracy: 0.0208
#
# Epoch 00063: val_loss did not improve from 0.45726
# Epoch 64/200
# 1085/1085 [==============================] - 177s 163ms/step - loss: 0.4563 - accuracy: 0.0208 - val_loss: 0.4588 - val_accuracy: 0.0208
#
# Epoch 00064: val_loss did not improve from 0.45726
# Epoch 65/200
# 1085/1085 [==============================] - 169s 156ms/step - loss: 0.4562 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00065: val_loss did not improve from 0.45726
# Epoch 66/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4561 - accuracy: 0.0208 - val_loss: 0.4583 - val_accuracy: 0.0208
#
# Epoch 00066: val_loss did not improve from 0.45726
# Epoch 67/200
# 1085/1085 [==============================] - 171s 158ms/step - loss: 0.4561 - accuracy: 0.0208 - val_loss: 0.4582 - val_accuracy: 0.0208
#
# Epoch 00067: val_loss did not improve from 0.45726
# Epoch 68/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4560 - accuracy: 0.0208 - val_loss: 0.4583 - val_accuracy: 0.0208
#
# Epoch 00068: val_loss did not improve from 0.45726
# Epoch 69/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4560 - accuracy: 0.0208 - val_loss: 0.4584 - val_accuracy: 0.0208
#
# Epoch 00069: val_loss did not improve from 0.45726
# Epoch 70/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4559 - accuracy: 0.0208 - val_loss: 0.4575 - val_accuracy: 0.0208
#
# Epoch 00070: val_loss did not improve from 0.45726
# Epoch 71/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4559 - accuracy: 0.0208 - val_loss: 0.4590 - val_accuracy: 0.0208
#
# Epoch 00071: val_loss did not improve from 0.45726
# Epoch 72/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4559 - accuracy: 0.0208 - val_loss: 0.4573 - val_accuracy: 0.0208
#
# Epoch 00072: val_loss did not improve from 0.45726
# Epoch 73/200
# 1085/1085 [==============================] - 168s 155ms/step - loss: 0.4558 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00073: val_loss did not improve from 0.45726
# Epoch 74/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4557 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00074: val_loss improved from 0.45726 to 0.45700, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 75/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4557 - accuracy: 0.0208 - val_loss: 0.4582 - val_accuracy: 0.0208
#
# Epoch 00075: val_loss did not improve from 0.45700
# Epoch 76/200
# 1085/1085 [==============================] - 161s 149ms/step - loss: 0.4557 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00076: val_loss did not improve from 0.45700
# Epoch 77/200
# 1085/1085 [==============================] - 162s 149ms/step - loss: 0.4557 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00077: val_loss did not improve from 0.45700
# Epoch 78/200
# 1085/1085 [==============================] - 159s 147ms/step - loss: 0.4556 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00078: val_loss did not improve from 0.45700
# Epoch 79/200
# 1085/1085 [==============================] - 162s 150ms/step - loss: 0.4556 - accuracy: 0.0208 - val_loss: 0.4571 - val_accuracy: 0.0208
#
# Epoch 00079: val_loss did not improve from 0.45700
# Epoch 80/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4556 - accuracy: 0.0208 - val_loss: 0.4587 - val_accuracy: 0.0208
#
# Epoch 00080: val_loss did not improve from 0.45700
# Epoch 81/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4556 - accuracy: 0.0208 - val_loss: 0.4571 - val_accuracy: 0.0208
#
# Epoch 00081: val_loss did not improve from 0.45700
# Epoch 82/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4556 - accuracy: 0.0208 - val_loss: 0.4585 - val_accuracy: 0.0208
#
# Epoch 00082: val_loss did not improve from 0.45700
# Epoch 83/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4556 - accuracy: 0.0208 - val_loss: 0.4576 - val_accuracy: 0.0208
#
# Epoch 00083: val_loss did not improve from 0.45700
# Epoch 84/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4555 - accuracy: 0.0208 - val_loss: 0.4581 - val_accuracy: 0.0208
#
# Epoch 00084: val_loss did not improve from 0.45700
# Epoch 85/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4555 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00085: val_loss did not improve from 0.45700
# Epoch 86/200
# 1085/1085 [==============================] - 162s 149ms/step - loss: 0.4555 - accuracy: 0.0208 - val_loss: 0.4569 - val_accuracy: 0.0208
#
# Epoch 00086: val_loss improved from 0.45700 to 0.45688, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 87/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4555 - accuracy: 0.0208 - val_loss: 0.4589 - val_accuracy: 0.0208
#
# Epoch 00087: val_loss did not improve from 0.45688
# Epoch 88/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4555 - accuracy: 0.0208 - val_loss: 0.4571 - val_accuracy: 0.0208
#
# Epoch 00088: val_loss did not improve from 0.45688
# Epoch 89/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4555 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00089: val_loss did not improve from 0.45688
# Epoch 90/200
# 1085/1085 [==============================] - 162s 149ms/step - loss: 0.4554 - accuracy: 0.0208 - val_loss: 0.4577 - val_accuracy: 0.0208
#
# Epoch 00090: val_loss did not improve from 0.45688
# Epoch 91/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4554 - accuracy: 0.0208 - val_loss: 0.4576 - val_accuracy: 0.0208
#
# Epoch 00091: val_loss did not improve from 0.45688
# Epoch 92/200
# 1085/1085 [==============================] - 160s 147ms/step - loss: 0.4555 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00092: val_loss did not improve from 0.45688
# Epoch 93/200
# 1085/1085 [==============================] - 165s 153ms/step - loss: 0.4554 - accuracy: 0.0208 - val_loss: 0.4571 - val_accuracy: 0.0208
#
# Epoch 00093: val_loss did not improve from 0.45688
# Epoch 94/200
# 1085/1085 [==============================] - 161s 149ms/step - loss: 0.4553 - accuracy: 0.0208 - val_loss: 0.4583 - val_accuracy: 0.0208
#
# Epoch 00094: val_loss did not improve from 0.45688
# Epoch 95/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4553 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00095: val_loss did not improve from 0.45688
# Epoch 96/200
# 1085/1085 [==============================] - 161s 149ms/step - loss: 0.4553 - accuracy: 0.0208 - val_loss: 0.4583 - val_accuracy: 0.0208
#
# Epoch 00096: val_loss did not improve from 0.45688
# Epoch 97/200
# 1085/1085 [==============================] - 161s 149ms/step - loss: 0.4553 - accuracy: 0.0208 - val_loss: 0.4568 - val_accuracy: 0.0208
#
# Epoch 00097: val_loss improved from 0.45688 to 0.45679, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 98/200
# 1085/1085 [==============================] - 161s 149ms/step - loss: 0.4552 - accuracy: 0.0208 - val_loss: 0.4578 - val_accuracy: 0.0208
#
# Epoch 00098: val_loss did not improve from 0.45679
# Epoch 99/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4551 - accuracy: 0.0208 - val_loss: 0.4575 - val_accuracy: 0.0208
#
# Epoch 00099: val_loss did not improve from 0.45679
# Epoch 100/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4551 - accuracy: 0.0208 - val_loss: 0.4568 - val_accuracy: 0.0208
#
# Epoch 00100: val_loss did not improve from 0.45679
# Epoch 101/200
# 1085/1085 [==============================] - 159s 147ms/step - loss: 0.4550 - accuracy: 0.0208 - val_loss: 0.4583 - val_accuracy: 0.0208
#
# Epoch 00101: val_loss did not improve from 0.45679
# Epoch 102/200
# 1085/1085 [==============================] - 162s 149ms/step - loss: 0.4550 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00102: val_loss improved from 0.45679 to 0.45648, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 103/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4550 - accuracy: 0.0208 - val_loss: 0.4580 - val_accuracy: 0.0208
#
# Epoch 00103: val_loss did not improve from 0.45648
# Epoch 104/200
# 1085/1085 [==============================] - 161s 148ms/step - loss: 0.4550 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00104: val_loss improved from 0.45648 to 0.45646, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 105/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4549 - accuracy: 0.0208 - val_loss: 0.4569 - val_accuracy: 0.0208
#
# Epoch 00105: val_loss did not improve from 0.45646
# Epoch 106/200
# 1085/1085 [==============================] - 161s 148ms/step - loss: 0.4549 - accuracy: 0.0208 - val_loss: 0.4583 - val_accuracy: 0.0208
#
# Epoch 00106: val_loss did not improve from 0.45646
# Epoch 107/200
# 1085/1085 [==============================] - 160s 147ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4562 - val_accuracy: 0.0208
#
# Epoch 00107: val_loss improved from 0.45646 to 0.45623, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 108/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4582 - val_accuracy: 0.0208
#
# Epoch 00108: val_loss did not improve from 0.45623
# Epoch 109/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4549 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00109: val_loss did not improve from 0.45623
# Epoch 110/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4578 - val_accuracy: 0.0208
#
# Epoch 00110: val_loss did not improve from 0.45623
# Epoch 111/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00111: val_loss did not improve from 0.45623
# Epoch 112/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00112: val_loss did not improve from 0.45623
# Epoch 113/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00113: val_loss did not improve from 0.45623
# Epoch 114/200
# 1085/1085 [==============================] - 158s 145ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4561 - val_accuracy: 0.0208
#
# Epoch 00114: val_loss improved from 0.45623 to 0.45607, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 115/200
# 1085/1085 [==============================] - 168s 155ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4577 - val_accuracy: 0.0208
#
# Epoch 00115: val_loss did not improve from 0.45607
# Epoch 116/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00116: val_loss did not improve from 0.45607
# Epoch 117/200
# 1085/1085 [==============================] - 170s 157ms/step - loss: 0.4548 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00117: val_loss did not improve from 0.45607
# Epoch 118/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4547 - accuracy: 0.0208 - val_loss: 0.4574 - val_accuracy: 0.0208
#
# Epoch 00118: val_loss did not improve from 0.45607
# Epoch 119/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4547 - accuracy: 0.0208 - val_loss: 0.4561 - val_accuracy: 0.0208
#
# Epoch 00119: val_loss did not improve from 0.45607
# Epoch 120/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4547 - accuracy: 0.0208 - val_loss: 0.4577 - val_accuracy: 0.0208
#
# Epoch 00120: val_loss did not improve from 0.45607
# Epoch 121/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4547 - accuracy: 0.0208 - val_loss: 0.4561 - val_accuracy: 0.0208
#
# Epoch 00121: val_loss did not improve from 0.45607
# Epoch 122/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4547 - accuracy: 0.0208 - val_loss: 0.4574 - val_accuracy: 0.0208
#
# Epoch 00122: val_loss did not improve from 0.45607
# Epoch 123/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4547 - accuracy: 0.0208 - val_loss: 0.4562 - val_accuracy: 0.0208
#
# Epoch 00123: val_loss did not improve from 0.45607
# Epoch 124/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4577 - val_accuracy: 0.0208
#
# Epoch 00124: val_loss did not improve from 0.45607
# Epoch 125/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4562 - val_accuracy: 0.0208
#
# Epoch 00125: val_loss did not improve from 0.45607
# Epoch 126/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4577 - val_accuracy: 0.0208
#
# Epoch 00126: val_loss did not improve from 0.45607
# Epoch 127/200
# 1085/1085 [==============================] - 171s 158ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4557 - val_accuracy: 0.0208
#
# Epoch 00127: val_loss improved from 0.45607 to 0.45571, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 128/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4586 - val_accuracy: 0.0208
#
# Epoch 00128: val_loss did not improve from 0.45571
# Epoch 129/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4578 - val_accuracy: 0.0208
#
# Epoch 00129: val_loss did not improve from 0.45571
# Epoch 130/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00130: val_loss did not improve from 0.45571
# Epoch 131/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00131: val_loss did not improve from 0.45571
# Epoch 132/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4568 - val_accuracy: 0.0208
#
# Epoch 00132: val_loss did not improve from 0.45571
# Epoch 133/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00133: val_loss did not improve from 0.45571
# Epoch 134/200
# 1085/1085 [==============================] - 170s 157ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4566 - val_accuracy: 0.0208
#
# Epoch 00134: val_loss did not improve from 0.45571
# Epoch 135/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00135: val_loss did not improve from 0.45571
# Epoch 136/200
# 1085/1085 [==============================] - 168s 154ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4557 - val_accuracy: 0.0208
#
# Epoch 00136: val_loss did not improve from 0.45571
# Epoch 137/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00137: val_loss did not improve from 0.45571
# Epoch 138/200
# 1085/1085 [==============================] - 169s 155ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00138: val_loss did not improve from 0.45571
# Epoch 139/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4573 - val_accuracy: 0.0208
#
# Epoch 00139: val_loss did not improve from 0.45571
# Epoch 140/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00140: val_loss did not improve from 0.45571
# Epoch 141/200
# 1085/1085 [==============================] - 161s 149ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4569 - val_accuracy: 0.0208
#
# Epoch 00141: val_loss did not improve from 0.45571
# Epoch 142/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4546 - accuracy: 0.0208 - val_loss: 0.4576 - val_accuracy: 0.0208
#
# Epoch 00142: val_loss did not improve from 0.45571
# Epoch 143/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4569 - val_accuracy: 0.0208
#
# Epoch 00143: val_loss did not improve from 0.45571
# Epoch 144/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4585 - val_accuracy: 0.0208
#
# Epoch 00144: val_loss did not improve from 0.45571
# Epoch 145/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4561 - val_accuracy: 0.0208
#
# Epoch 00145: val_loss did not improve from 0.45571
# Epoch 146/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4569 - val_accuracy: 0.0208
#
# Epoch 00146: val_loss did not improve from 0.45571
# Epoch 147/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4545 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00147: val_loss did not improve from 0.45571
# Epoch 148/200
# 1085/1085 [==============================] - 161s 149ms/step - loss: 0.4544 - accuracy: 0.0208 - val_loss: 0.4568 - val_accuracy: 0.0208
#
# Epoch 00148: val_loss did not improve from 0.45571
# Epoch 149/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4543 - accuracy: 0.0208 - val_loss: 0.4571 - val_accuracy: 0.0208
#
# Epoch 00149: val_loss did not improve from 0.45571
# Epoch 150/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4543 - accuracy: 0.0208 - val_loss: 0.4568 - val_accuracy: 0.0208
#
# Epoch 00150: val_loss did not improve from 0.45571
# Epoch 151/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4543 - accuracy: 0.0208 - val_loss: 0.4560 - val_accuracy: 0.0208
#
# Epoch 00151: val_loss did not improve from 0.45571
# Epoch 152/200
# 1085/1085 [==============================] - 161s 148ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4577 - val_accuracy: 0.0208
#
# Epoch 00152: val_loss did not improve from 0.45571
# Epoch 153/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4562 - val_accuracy: 0.0208
#
# Epoch 00153: val_loss did not improve from 0.45571
# Epoch 154/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4567 - val_accuracy: 0.0208
#
# Epoch 00154: val_loss did not improve from 0.45571
# Epoch 155/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4568 - val_accuracy: 0.0208
#
# Epoch 00155: val_loss did not improve from 0.45571
# Epoch 156/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4564 - val_accuracy: 0.0208
#
# Epoch 00156: val_loss did not improve from 0.45571
# Epoch 157/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4576 - val_accuracy: 0.0208
#
# Epoch 00157: val_loss did not improve from 0.45571
# Epoch 158/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4557 - val_accuracy: 0.0208
#
# Epoch 00158: val_loss improved from 0.45571 to 0.45567, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 159/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4574 - val_accuracy: 0.0208
#
# Epoch 00159: val_loss did not improve from 0.45567
# Epoch 160/200
# 1085/1085 [==============================] - 169s 156ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4562 - val_accuracy: 0.0208
#
# Epoch 00160: val_loss did not improve from 0.45567
# Epoch 161/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4566 - val_accuracy: 0.0208
#
# Epoch 00161: val_loss did not improve from 0.45567
# Epoch 162/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00162: val_loss did not improve from 0.45567
# Epoch 163/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4562 - val_accuracy: 0.0208
#
# Epoch 00163: val_loss did not improve from 0.45567
# Epoch 164/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4577 - val_accuracy: 0.0208
#
# Epoch 00164: val_loss did not improve from 0.45567
# Epoch 165/200
# 1085/1085 [==============================] - 169s 156ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4554 - val_accuracy: 0.0208
#
# Epoch 00165: val_loss improved from 0.45567 to 0.45544, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 166/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4542 - accuracy: 0.0208 - val_loss: 0.4568 - val_accuracy: 0.0208
#
# Epoch 00166: val_loss did not improve from 0.45544
# Epoch 167/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4566 - val_accuracy: 0.0208
#
# Epoch 00167: val_loss did not improve from 0.45544
# Epoch 168/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00168: val_loss did not improve from 0.45544
# Epoch 169/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4540 - accuracy: 0.0208 - val_loss: 0.4574 - val_accuracy: 0.0208
#
# Epoch 00169: val_loss did not improve from 0.45544
# Epoch 170/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4540 - accuracy: 0.0208 - val_loss: 0.4557 - val_accuracy: 0.0208
#
# Epoch 00170: val_loss did not improve from 0.45544
# Epoch 171/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4540 - accuracy: 0.0208 - val_loss: 0.4575 - val_accuracy: 0.0208
#
# Epoch 00171: val_loss did not improve from 0.45544
# Epoch 172/200
# 1085/1085 [==============================] - 166s 153ms/step - loss: 0.4539 - accuracy: 0.0208 - val_loss: 0.4559 - val_accuracy: 0.0208
#
# Epoch 00172: val_loss did not improve from 0.45544
# Epoch 173/200
# 1085/1085 [==============================] - 159s 147ms/step - loss: 0.4540 - accuracy: 0.0208 - val_loss: 0.4562 - val_accuracy: 0.0208
#
# Epoch 00173: val_loss did not improve from 0.45544
# Epoch 174/200
# 1085/1085 [==============================] - 160s 147ms/step - loss: 0.4540 - accuracy: 0.0208 - val_loss: 0.4569 - val_accuracy: 0.0208
#
# Epoch 00174: val_loss did not improve from 0.45544
# Epoch 175/200
# 1085/1085 [==============================] - 160s 147ms/step - loss: 0.4540 - accuracy: 0.0208 - val_loss: 0.4559 - val_accuracy: 0.0208
#
# Epoch 00175: val_loss did not improve from 0.45544
# Epoch 176/200
# 1085/1085 [==============================] - 165s 152ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4579 - val_accuracy: 0.0208
#
# Epoch 00176: val_loss did not improve from 0.45544
# Epoch 177/200
# 1085/1085 [==============================] - 167s 154ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4563 - val_accuracy: 0.0208
#
# Epoch 00177: val_loss did not improve from 0.45544
# Epoch 178/200
# 1085/1085 [==============================] - 159s 147ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4558 - val_accuracy: 0.0208
#
# Epoch 00178: val_loss did not improve from 0.45544
# Epoch 179/200
# 1085/1085 [==============================] - 162s 149ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4566 - val_accuracy: 0.0208
#
# Epoch 00179: val_loss did not improve from 0.45544
# Epoch 180/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4564 - val_accuracy: 0.0208
#
# Epoch 00180: val_loss did not improve from 0.45544
# Epoch 181/200
# 1085/1085 [==============================] - 162s 149ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00181: val_loss did not improve from 0.45544
# Epoch 182/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4540 - accuracy: 0.0208 - val_loss: 0.4558 - val_accuracy: 0.0208
#
# Epoch 00182: val_loss did not improve from 0.45544
# Epoch 183/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4578 - val_accuracy: 0.0208
#
# Epoch 00183: val_loss did not improve from 0.45544
# Epoch 184/200
# 1085/1085 [==============================] - 162s 150ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4556 - val_accuracy: 0.0208
#
# Epoch 00184: val_loss did not improve from 0.45544
# Epoch 185/200
# 1085/1085 [==============================] - 162s 149ms/step - loss: 0.4541 - accuracy: 0.0208 - val_loss: 0.4558 - val_accuracy: 0.0208
#
# Epoch 00185: val_loss did not improve from 0.45544
# Epoch 186/200
# 1085/1085 [==============================] - 162s 150ms/step - loss: 0.4540 - accuracy: 0.0208 - val_loss: 0.4570 - val_accuracy: 0.0208
#
# Epoch 00186: val_loss did not improve from 0.45544
# Epoch 187/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4539 - accuracy: 0.0208 - val_loss: 0.4566 - val_accuracy: 0.0208
#
# Epoch 00187: val_loss did not improve from 0.45544
# Epoch 188/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4538 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00188: val_loss did not improve from 0.45544
# Epoch 189/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4539 - accuracy: 0.0208 - val_loss: 0.4576 - val_accuracy: 0.0208
#
# Epoch 00189: val_loss did not improve from 0.45544
# Epoch 190/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4539 - accuracy: 0.0208 - val_loss: 0.4553 - val_accuracy: 0.0208
#
# Epoch 00190: val_loss improved from 0.45544 to 0.45532, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5
# Epoch 191/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4539 - accuracy: 0.0208 - val_loss: 0.4565 - val_accuracy: 0.0208
#
# Epoch 00191: val_loss did not improve from 0.45532
# Epoch 192/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4539 - accuracy: 0.0208 - val_loss: 0.4558 - val_accuracy: 0.0208
#
# Epoch 00192: val_loss did not improve from 0.45532
# Epoch 193/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4538 - accuracy: 0.0208 - val_loss: 0.4569 - val_accuracy: 0.0208
#
# Epoch 00193: val_loss did not improve from 0.45532
# Epoch 194/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4537 - accuracy: 0.0208 - val_loss: 0.4572 - val_accuracy: 0.0208
#
# Epoch 00194: val_loss did not improve from 0.45532
# Epoch 195/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4537 - accuracy: 0.0208 - val_loss: 0.4555 - val_accuracy: 0.0208
#
# Epoch 00195: val_loss did not improve from 0.45532
# Epoch 196/200
# 1085/1085 [==============================] - 163s 151ms/step - loss: 0.4536 - accuracy: 0.0208 - val_loss: 0.4569 - val_accuracy: 0.0208
#
# Epoch 00196: val_loss did not improve from 0.45532
# Epoch 197/200
# 1085/1085 [==============================] - 164s 151ms/step - loss: 0.4536 - accuracy: 0.0208 - val_loss: 0.4560 - val_accuracy: 0.0208
#
# Epoch 00197: val_loss did not improve from 0.45532
# Epoch 198/200
# 1085/1085 [==============================] - 160s 148ms/step - loss: 0.4536 - accuracy: 0.0208 - val_loss: 0.4566 - val_accuracy: 0.0208
#
# Epoch 00198: val_loss did not improve from 0.45532
# Epoch 199/200
# 1085/1085 [==============================] - 163s 150ms/step - loss: 0.4535 - accuracy: 0.0208 - val_loss: 0.4564 - val_accuracy: 0.0208
#
# Epoch 00199: val_loss did not improve from 0.45532
# Epoch 200/200
# 1085/1085 [==============================] - 161s 148ms/step - loss: 0.4534 - accuracy: 0.0208 - val_loss: 0.4552 - val_accuracy: 0.0208
#
# Epoch 00200: val_loss improved from 0.45532 to 0.45517, saving model to /content/drive/MyDrive/ProyectoDeepLearningUC/notebooks/model_QandA.h5

# %% [markdown]
# ## 6. Test the model

# %%
def reply(paragraph, question):
    input_paragraph_seq = []
    input_question_seq = []
    input_paragraph_emb = []
    input_question_emb = []
    input_paragraph_text = paragraph.lower()
    input_question_text = question.lower()
    for word in nltk.word_tokenize(input_paragraph_text):
        if not in_white_list(word):
            continue
        emb = encode_word(word)
        input_paragraph_emb.append(emb)
    for word in nltk.word_tokenize(input_question_text):
        if not in_white_list(word):
            continue
        emb = encode_word(word)
        input_question_emb.append(emb)
    input_paragraph_seq.append(input_paragraph_emb)
    input_question_seq.append(input_question_emb)
    input_paragraph_seq = pad_sequences(input_paragraph_seq, input_paragraph_max_seq_length)
    input_question_seq = pad_sequences(input_question_seq, input_question_max_seq_length)
    states_value = encoder_model.predict([input_paragraph_seq, input_question_seq])
    target_seq = np.zeros((1, 1, num_target_tokens))
    target_seq[0, 0, target_word2idx['START']] = 1
    target_text = ''
    target_text_len = 0
    terminated = False
    while not terminated:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sample_token_idx = np.argmax(output_tokens[0, -1, :])
        sample_word = target_idx2word[sample_token_idx]
        target_text_len += 1

        if sample_word != 'START' and sample_word != 'END':
            target_text += ' ' + sample_word

        if sample_word == 'END' or target_text_len >= target_max_seq_length:
            terminated = True

        target_seq = np.zeros((1, 1, num_target_tokens))
        target_seq[0, 0, sample_token_idx] = 1

        states_value = [h, c]
    return target_text.strip()

# %%
for i in range(20):
    index = i * 150
    paragraph, question, actual_answer = data[index]
    predicted_answer = reply(paragraph, question)
    print('context: ', paragraph)
    print('question: ', question)
    print({'guessed_answer': predicted_answer, 'actual_answer': actual_answer})
    print("\n")
# Out:
# context:  Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
# question:  When did Beyonce start becoming popular?
# {'guessed_answer': '', 'actual_answer': 'in the late 1990s'}
#
#
# context:  Beyoncé's second solo album B'Day was released on September 5, 2006, in the US, to coincide with her twenty-fifth birthday. It sold 541,000 copies in its first week and debuted atop the Billboard 200, becoming Beyoncé's second consecutive number-one album in the United States. The album's lead single "Déjà Vu", featuring Jay Z, reached the top five on the Billboard Hot 100 chart. The second international single "Irreplaceable" was a commercial success worldwide, reaching number one in Australia, Hungary, Ireland, New Zealand and the United States. B'Day also produced three other singles; "Ring the Alarm", "Get Me Bodied", and "Green Light" (released in the United Kingdom only).
# question:  The lead single from the album was which song?
# {'guessed_answer': '', 'actual_answer': 'Déjà Vu'}
#
#
# context:  At the 57th Annual Grammy Awards in February 2015, Beyoncé was nominated for six awards, ultimately winning three: Best R&B Performance and Best R&B Song for "Drunk in Love", and Best Surround Sound Album for Beyoncé. She was nominated for Album of the Year but the award was won by Beck for his Morning Phase album. In August, the cover of the September issue of Vogue magazine was unveiled online, Beyoncé as the cover star, becoming the first African-American artist and third African-American woman in general to cover the September issue. She headlined the 2015 Made in America festival in early September and also the Global Citizen Festival later that month. Beyoncé made an uncredited featured appearance on the track "Hymn for the Weekend" by British rock band Coldplay, on their seventh studio album A Head Full of Dreams (2015), which saw release in December. On January 7, 2016, Pepsi announced Beyoncé would perform alongside Coldplay at Super Bowl 50 in February. Knowles has previously performed at four Super Bowl shows throughout her career, serving as the main headliner of the 47th Super Bowl halftime show in 2013.
# question:  Which artist beat Beyonce out for Album of the year?
# {'guessed_answer': '', 'actual_answer': 'Beck'}
#
#
# context:  In 2001, she became the first African-American woman and second woman songwriter to win the Pop Songwriter of the Year award at the American Society of Composers, Authors, and Publishers Pop Music Awards. Beyoncé was the third woman to have writing credits on three number one songs ("Irreplaceable", "Grillz" and "Check on It") in the same year, after Carole King in 1971 and Mariah Carey in 1991. She is tied with American songwriter Diane Warren at third with nine songwriting credits on number-one singles. (The latter wrote her 9/11-motivated song "I Was Here" for 4.) In May 2011, Billboard magazine listed Beyoncé at number 17 on their list of the "Top 20 Hot 100 Songwriters", for having co-written eight singles that hit number one on the Billboard Hot 100 chart. She was one of only three women on that list.
# question:  What did Beyoncé win in 2001, making her the first black woman to do so?
# {'guessed_answer': '', 'actual_answer': 'Pop Songwriter of the Year award'}
#
#
# context:  Her debut single, "Crazy in Love" was named VH1's "Greatest Song of the 2000s", NME's "Best Track of the 00s" and "Pop Song of the Century", considered by Rolling Stone to be one of the 500 greatest songs of all time, earned two Grammy Awards and is one of the best-selling singles of all time at around 8 million copies. The music video for "Single Ladies (Put a Ring on It)", which achieved fame for its intricate choreography and its deployment of jazz hands, was credited by the Toronto Star as having started the "first major dance craze of both the new millennium and the Internet", triggering a number of parodies of the dance choreography and a legion of amateur imitators on YouTube. In 2013, Drake released a single titled "Girls Love Beyoncé", which featured an interpolation from Destiny Child's "Say My Name" and discussed his relationship with women. In January 2012, research scientist Bryan Lessard named Scaptia beyonceae, a species of horse fly found in Northern Queensland, Australia after Beyoncé due to the fly's unique golden hairs on its abdomen. In July 2014, a Beyoncé exhibit was introduced into the "Legends of Rock" section of the Rock and Roll Hall of Fame. The black leotard from the "Single Ladies" video and her outfit from the Super Bowl half time performance are among several pieces housed at the museum.
# question:  How many did Crazy in Love sell to become one of the greatest selling singles in history?
# {'guessed_answer': '', 'actual_answer': '8 million'}
#
#
# context:  In December, Beyoncé along with a variety of other celebrities teamed up and produced a video campaign for "Demand A Plan", a bipartisan effort by a group of 950 US mayors and others designed to influence the federal government into rethinking its gun control laws, following the Sandy Hook Elementary School shooting. Beyoncé became an ambassador for the 2012 World Humanitarian Day campaign donating her song "I Was Here" and its music video, shot in the UN, to the campaign. In 2013, it was announced that Beyoncé would work with Salma Hayek and Frida Giannini on a Gucci "Chime for Change" campaign that aims to spread female empowerment. The campaign, which aired on February 28, was set to her new music. A concert for the cause took place on June 1, 2013 in London and included other acts like Ellie Goulding, Florence and the Machine, and Rita Ora. In advance of the concert, she appeared in a campaign video released on 15 May 2013, where she, along with Cameron Diaz, John Legend and Kylie Minogue, described inspiration from their mothers, while a number of other artists celebrated personal inspiration from other women, leading to a call for submission of photos of women of viewers' inspiration from which a selection was shown at the concert. Beyoncé said about her mother Tina Knowles that her gift was "finding the best qualities in every human being." With help of the crowdfunding platform Catapult, visitors of the concert could choose between several projects promoting education of women and girls. Beyoncé is also taking part in "Miss a Meal", a food-donation campaign, and supporting Goodwill charity through online charity auctions at Charitybuzz that support job creation throughout Europe and the U.S.
# question:  What school shooting prompted the creation of Demand A Plan?
# {'guessed_answer': '', 'actual_answer': 'Sandy Hook Elementary School'}
#
#
# context:  From September 1823 to 1826 Chopin attended the Warsaw Lyceum, where he received organ lessons from the Czech musician Wilhelm Würfel during his first year. In the autumn of 1826 he began a three-year course under the Silesian composer Józef Elsner at the Warsaw Conservatory, studying music theory, figured bass and composition.[n 3] Throughout this period he continued to compose and to give recitals in concerts and salons in Warsaw. He was engaged by the inventors of a mechanical organ, the "eolomelodicon", and on this instrument in May 1825 he performed his own improvisation and part of a concerto by Moscheles. The success of this concert led to an invitation to give a similar recital on the instrument before Tsar Alexander I, who was visiting Warsaw; the Tsar presented him with a diamond ring. At a subsequent eolomelodicon concert on 10 June 1825, Chopin performed his Rondo Op. 1. This was the first of his works to be commercially published and earned him his first mention in the foreign press, when the Leipzig Allgemeine Musikalische Zeitung praised his "wealth of musical ideas".
# question:  What is the title of his first commercially successful work?
# {'guessed_answer': '', 'actual_answer': 'Rondo Op. 1.'}
#
#
# context:  The two became friends, and for many years lived in close proximity in Paris, Chopin at 38 Rue de la Chaussée-d'Antin, and Liszt at the Hôtel de France on the Rue Lafitte, a few blocks away. They performed together on seven occasions between 1833 and 1841. The first, on 2 April 1833, was at a benefit concert organized by Hector Berlioz for his bankrupt Shakespearean actress wife Harriet Smithson, during which they played George Onslow's Sonata in F minor for piano duet. Later joint appearances included a benefit concert for the Benevolent Association of Polish Ladies in Paris. Their last appearance together in public was for a charity concert conducted for the Beethoven Memorial in Bonn, held at the Salle Pleyel and the Paris Conservatory on 25 and 26 April 1841.
# question:  When was the first time Liszt and Chopin performed together?
# {'guessed_answer': '', 'actual_answer': '2 April 1833'}
#
#
# context:  Chopin has figured extensively in Polish literature, both in serious critical studies of his life and music and in fictional treatments. The earliest manifestation was probably an 1830 sonnet on Chopin by Leon Ulrich. French writers on Chopin (apart from Sand) have included Marcel Proust and André Gide; and he has also featured in works of Gottfried Benn and Boris Pasternak. There are numerous biographies of Chopin in English (see bibliography for some of these).
# question:  When did Ulrich do his sonnet on Chopin?
# {'guessed_answer': '', 'actual_answer': '1830'}
#
#
# context:  Works published since 1857 have received alternative catalogue designations instead of opus numbers. The present standard musicological reference for Chopin's works is the Kobylańska Catalogue (usually represented by the initials 'KK'), named for its compiler, the Polish musicologist Krystyna Kobylańska.
# question:  What is the shortened reference for the Kobylańska Catalogue?
# {'guessed_answer': '', 'actual_answer': 'KK'}
#
#
# context:  As evident in his imperial edicts, the Hongwu Emperor was well aware of the Buddhist link between Tibet and China and wanted to foster it. Rolpe Dorje, 4th Karmapa Lama (1340–1383) rejected the Hongwu Emperor's invitation, although he did send some disciples as envoys to the court in Nanjing. The Hongwu Emperor also entrusted his guru Zongluo, one of many Buddhist monks at court, to head a religious mission into Tibet in 1378–1382 in order to obtain Buddhist texts.
# question:  Who did Rolpe Dorje send as envoys to court in Nanjing?
# {'guessed_answer': '', 'actual_answer': 'disciples'}
#
#
# context:  Historians Luciano Petech and Sato Hisashi argue that the Ming upheld a "divide-and-rule" policy towards a weak and politically fragmented Tibet after the Sakya regime had fallen. Chan writes that this was perhaps the calculated strategy of the Yongle Emperor, as exclusive patronage to one Tibetan sect would have given it too much regional power. Sperling finds no textual evidence in either Chinese or Tibetan sources to support this thesis of Petech and Hisashi. Norbu asserts that their thesis is largely based on the list of Ming titles conferred on Tibetan lamas rather than "comparative analysis of developments in China and Tibet." Rossabi states that this theory "attributes too much influence to the Chinese," pointing out that Tibet was already politically divided when the Ming dynasty began. Rossabi also discounts the "divide-and-rule" theory on the grounds of the Yongle Emperor's failed attempt to build a strong relationship with the fifth Karmapa—one which he hoped would parallel Kublai Khan's earlier relationship with the Sakya Phagpa lama. Instead, the Yongle Emperor followed the Karmapa's advice of giving patronage to many different Tibetan lamas.
# question:  Who did Yongle Emperor fail to build a solid relationship with?
# {'guessed_answer': '', 'actual_answer': 'fifth Karmapa'}
#
#
# context:  In September 2007, during a lawsuit with patent holding company Burst.com, Apple drew attention to a patent for a similar device that was developed in 1979. Kane Kramer applied for a UK patent for his design of a "plastic music box" in 1981, which he called the IXI. He was unable to secure funding to renew the US$120,000 worldwide patent, so it lapsed and Kramer never profited from his idea.
# question:  What did Kane Kramer call the device for which he wanted a patent?
# {'guessed_answer': '', 'actual_answer': 'IXI'}
#
#
# context:  iTunes 7 and above can transfer purchased media of the iTunes Store from an iPod to a computer, provided that computer containing the DRM protected media is authorized to play it.
# question:  What minimum version of iTunes is required to transfer purchased media from an iPod to an authorized computer?
# {'guessed_answer': '', 'actual_answer': 'iTunes 7'}
#
#
# context:  The context-sensitive button mechanic allows one button to serve a variety of functions, such as talking, opening doors, and pushing, pulling, and throwing objects.[e] The on-screen display shows what action, if any, the button will trigger, determined by the situation. For example, if Link is holding a rock, the context-sensitive button will cause Link to throw the rock if he is moving or targeting an object or enemy, or place the rock on the ground if he is standing still.[f]
# question:  What mechanic allows one button to serve many functions?
# {'guessed_answer': '', 'actual_answer': 'context-sensitive button mechanic'}
#
#
# context:  Twilight Princess was released to universal critical acclaim and commercial success. It received perfect scores from major publications such as 1UP.com, Computer and Video Games, Electronic Gaming Monthly, Game Informer, GamesRadar, and GameSpy. On the review aggregators GameRankings and Metacritic, Twilight Princess has average scores of 95% and 95 for the Wii version and scores of 95% and 96 for the GameCube version. GameTrailers in their review called it one of the greatest games ever created.
# question:  Which sites gave the Wii copy of Twilight Princess scores of 95% and 95?
# {'guessed_answer': '', 'actual_answer': 'GameRankings and Metacritic'}
#
#
# context:  In addition to the principal cast, Alessandro Cremona was cast as Marco Sciarra, Stephanie Sigman was cast as Estrella, and Detlef Bothe was cast as a villain for scenes shot in Austria. In February 2015 over fifteen hundred extras were hired for the pre-title sequence set in Mexico, though they were duplicated in the film, giving the effect of around ten thousand extras.
# question:  When was the opening scene of Spectre filmed?
# {'guessed_answer': '', 'actual_answer': 'February 2015'}
#
#
# context:  Christopher Orr, writing in The Atlantic, also criticised the film, saying that Spectre "backslides on virtually every [aspect]". Lawrence Toppman of The Charlotte Observer called Craig's performance "Bored, James Bored." Alyssa Rosenberg, writing for The Washington Post, stated that the film turned into "a disappointingly conventional Bond film."
# question:  What was the catch phrase Lawrence Toppman of the Charlotte Observer used for the film?
# {'guessed_answer': '', 'actual_answer': 'Bored, James Bored'}
#
#
# context:  Initially, officials were unable to contact the Wolong National Nature Reserve, home to around 280 giant pandas. However, the Foreign Ministry later said that a group of 31 British tourists visiting the Wolong Panda Reserve in the quake-hit area returned safe and uninjured to Chengdu. Nonetheless, the well-being of an even greater number of pandas in the neighbouring panda reserves remained unknown. Five security guards at the reserve were killed by the earthquake. Six pandas escaped after their enclosures were damaged. By May 20, two pandas at the reserve were found to be injured, while the search continued for another two adult pandas that went missing after the quake. By May 28, 2008, one panda was still missing. The missing panda was later found dead under the rubble of an enclosure. Nine-year-old Mao Mao, a mother of five at the breeding center, was discovered on Monday, her body crushed by a wall in her enclosure. Panda keepers and other workers placed her remains in a small wooden crate and buried her outside the breeding centre.
# question:  How many security guards died at the reserve?
# {'guessed_answer': '', 'actual_answer': 'five'}
#
#
# context:  In 2008, State Council established a counterpart support plan (《汶川地震灾后恢复重建对口支援方案》). The plan is to arrange 19 eastern and central province and municipalitie to help 18 counties, on "one province to one affected county" basis. The plan spanned 3 years, and cost no less than one percent of the province or municipality's budget.
# question:  What is the basis for this plan?
# {'guessed_answer': '', 'actual_answer': 'one province to one affected county'}
