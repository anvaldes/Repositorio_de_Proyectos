# %% [markdown]
# # TOMEK

# %% [markdown]
# ![TOMEK.png](data:image/png;base64,...)

# %% [markdown]
# # Steps

# %% [markdown]
# ### Step 1:

# %% [markdown]
# We have the majority class and the minority class.

# %% [markdown]
# ### Step 2:
#
# Consider the points near to the decisión line. Consider a pair of nearest points where each one comes from a different class.

# %% [markdown]
# ### Step 3:

# %% [markdown]
# Delete the component of the pair which belongs to the majority class.

# %% [markdown]
# ### Step 4:

# %% [markdown]
# Sometimes we apply SMOTE after Tomek

# %% [markdown]
# ### 1. Import Libraries

# %%
from collections import Counter
from imblearn.combine import SMOTETomek
from sklearn.datasets import make_classification

# %% [markdown]
# ### 2. Load Data

# %%
X, y = make_classification(
    n_classes = 2,
    class_sep = 2,
    weights = [0.1, 0.9],
    n_informative = 3,
    n_redundant = 1,
    flip_y = 0,
    n_features = 20,
    n_clusters_per_class = 1,
    n_samples = 1000,
    random_state = 10
    )

# %% [markdown]
# ### 3. Apply Method

# %%
print('Original dataset shape %s' % Counter(y))
# Out:
# Original dataset shape Counter({1: 900, 0: 100})

# %%
smt = SMOTETomek(random_state = 42)

# %%
X_res, y_res = smt.fit_resample(X, y)

# %%
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 900, 1: 900})
