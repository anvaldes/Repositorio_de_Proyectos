# %% [markdown]
# # Normalization vs Standarization

# %% [markdown]
# By Alberto Valdés
#
# **Mail 1:** anvaldes@uc.cl
#
# **Mail 2:** alberto.valdes.gonzalez.96@gmail.com

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Many times when we works with different dataset we affront to the decision of Standardized or Normalized one feature or field. For this reason we going to explain both transforms.

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from scipy import stats
from mlxtend.preprocessing import minmax_scaling
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Set seed**

# %%
np.random.seed(0)

# %%
original_data = np.random.exponential(size=1000)

# %% [markdown]
# # 1. Normalization

# %% [markdown]
# Normalization often also simply called Min-Max scaling basically shrinks the range of the data such that the range is fixed between 0 and 1.

# %% [markdown]
# $ Z_i = \cfrac{X_i - min_{j = 1, ..., n}(X_j)}{max_{j = 1, ..., n}(X_j) - min_{j = 1, ..., n}(X_j)} $

# %% [markdown]
# * This transformation works better than standarization when the standar desviation $ (\sigma) $ is very small.
# * This transformation doesn't work so well when we have outliers.
# * This transformation maintains the distribution.

# %%
scaled_data = minmax_scaling(original_data, columns=[0])

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title("Scaled data")
plt.show()

# %% [markdown]
# # 2. Standarization

# %% [markdown]
# Standardization (or Z-score normalization) is the process of rescaling the features so that they’ll have the properties of a Gaussian distribution with $ \mu = 0 $ and $ \sigma  = 1 $.

# %% [markdown]
# $ Z_i = \cfrac{X_i - \mu}{\sigma} $

# %% [markdown]
# * This transformation doesn't maintains the distribution.

# %%
normalized_data = stats.boxcox(original_data)

# %%
fig, ax=plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(normalized_data[0], ax=ax[1], kde=True, legend=False)
ax[1].set_title("Normalized data")
plt.show()
