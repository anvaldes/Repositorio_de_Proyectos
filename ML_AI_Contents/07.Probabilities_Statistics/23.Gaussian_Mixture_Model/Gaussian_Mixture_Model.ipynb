# %% [markdown]
# # Gaussian Mixture Model

# %% [markdown]
# By Alberto Valdés
#
# **Mail 1:** anvaldes@uc.cl
#
# **Mail 2:** alberto.valdes.gonzalez.96@gmail.com

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import time
import math
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import image as mpimg

# %%
from sklearn import datasets
from sklearn.mixture import GaussianMixture

# %%
def display_img(name, a, b):
    plt.figure(figsize = (a, b))
    image = mpimg.imread(name)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
start = time.time()

# %% [markdown]
# # Explanation

# %% [markdown]
# $ p(x) = \sum_{c} \pi_c \cdot N(x | \mu_c, \sigma_c) $
#
# $ r_{i, c} = \cfrac{\pi_c \cdot N(x | \mu_c, \sigma_c)}{\sum_{c'} \pi_c' \cdot N(x | \mu_c', \sigma_c')} $
#
# For each point $(i)$ choose the cluster $(c)$ with the highest $ r_{i, c} $.

# %% [markdown]
# ### M step
#
# For each $ c $ (cluster):
#
# $ \ $
#
# $ m_c = \sum_{i} r_{i, c} $
#
# $ \pi_c = \cfrac{m_c}{m} $
#
# $ \mu_c = \cfrac{1}{m_c} \sum_{i} r_{i, c} \cdot x^{(i)} $
#
# $ \Sigma_c = \cfrac{1}{m_c} \sum_{i} r_{i, c} \cdot (x^{(i)} - \mu_c)^T (x^{(i)} - \mu_c) $

# %%
iris = datasets.load_iris()
X = iris.data[:, :2]
df = pd.DataFrame(X)

# %%
plt.scatter(df[0], df[1])
plt.show()

# %%
gmm = GaussianMixture(n_components = 3)

# %%
gmm = gmm.fit(df)

# %%
labels = gmm.predict(df)
df['labels']= labels

# %%
df_0 = df[df['labels']== 0]
df_1 = df[df['labels']== 1]
df_2 = df[df['labels']== 2]

# %%
plt.scatter(df_0[0], df_0[1], c ='red')
plt.scatter(df_1[0], df_1[1], c ='blue')
plt.scatter(df_2[0], df_2[1], c ='green')
plt.show()

# %% [markdown]
# ### Time of execution

# %%
end = time.time()

# %%
delta = (end - start)

hours = int(delta/3600)
mins = int((delta - hours*3600)/60)
segs = int(delta - hours*3600 - mins*60)
print(f'Execute this notebook take us {hours} hours, {mins} minutes and {segs} seconds.')
# Out:
# Execute this notebook take us 0 hours, 0 minutes and 0 seconds.
