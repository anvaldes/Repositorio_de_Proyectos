# %% [markdown]
# # EDA Regression

# %% [markdown]
# By Alberto Valdés
#
# **Mail 1:** anvaldes@uc.cl
#
# **Mail 2:** alberto.valdes.gonzalez.96@gmail.com

# %% [markdown]
# Exploratory Data Analysis (EDA) is one of the techniques used for extracting vital features and trends used by machine learning and deep learning models in Data Science. Thus, EDA has become an important milestone for anyone working in data science.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import time
import scipy
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import image as mpimg

# %%
def display_img(name, a, b):
    plt.figure(figsize = (a, b))
    image = mpimg.imread(name)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
start = time.time()

# %% [markdown]
# # 1. Preprocessing

# %% [markdown]
# ### i. Read Dataframe

# %%
df = pd.read_csv('Life Expectancy Data.csv')

# %% [markdown]
# This dataset is about life expectancy of every country for every year.

# %%
X_cols = ['Year', 'Status', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 
          'Polio', 'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources', 'Schooling']

y_col = ['Life expectancy ']

# %% [markdown]
# ### ii. Drop 'y' NaNs

# %%
df = df[df[y_col[0]].notna()]

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ### i. Split

# %% [markdown]
# **a. Separate all data in train set and test sets**
#
# There can't be intersection of countries. The external countries we are consider are which are from South America.

# %%
display_img('Separation_1.png', 10, 10)

# %% [markdown]
# **b. Separate train set in train set and validation sets**
#
# There can't be intersection of countries.

# %%
display_img('Separation_2.png', 10, 10)

# %%
# External

ctr_test_hor_ext = ['Argentina', 'Bolivia (Plurinational State of)', 'Brazil', 'Peru', 'Uruguay']

ctr_test_ver_ext = ['Chile', 'Colombia', 'Ecuador', 'Paraguay', 'Venezuela (Bolivarian Republic of)']

# Internal

ctr_test_hor_int = ['Dominica', 'Mauritius', 'Netherlands', 'Armenia', 'Kazakhstan', 'Russian Federation', 'Ukraine', 'Bangladesh', 'India', 'Somalia']

ctr_test_ver_int = ['Afghanistan', 'New Zealand', 'Niger', 'Nigeria', 'Norway', 'Oman', 'Pakistan', 'Panama', 'Papua New Guinea', 'Philippines']

# Validation

ctr_val_hor = ['Albania', 'Qatar', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Nicaragua', 'Poland', 'Portugal', 'Republic of Korea', 'Senegal', 'Republic of Moldova', 
               'Romania', 'Rwanda', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Samoa', 'Sao Tome and Principe', 'Morocco', 'Montenegro']

ctr_val_ver = ['Algeria', 'Luxembourg', 'Sierra Leone', 'Seychelles', 'Serbia', 'Saudi Arabia', 'Mongolia', 'Micronesia (Federated States of)', 'Mexico',
               'Mauritania', 'Malta', 'Mali', 'Maldives', 'Malaysia', 'Malawi', 'Madagascar', 'Lithuania', 'Slovakia', 'Libya', 'Liberia']

# All validation and test countries

all_ctr = ctr_test_hor_ext + ctr_test_ver_ext + ctr_test_hor_int + ctr_test_ver_int + ctr_val_hor + ctr_val_ver

# %%
# External

df_test_hor_ext = df[(df['Country'].isin(ctr_test_hor_ext)) & (df['Year'] != 2015)]
df_test_ver_ext = df[(df['Country'].isin(ctr_test_ver_ext)) & (df['Year'] == 2015)]

# Internal

df_test_hor_int = df[(df['Country'].isin(ctr_test_hor_int)) & (df['Year'] != 2015)]
df_test_ver_int = df[(df['Country'].isin(ctr_test_ver_int)) & (df['Year'] == 2015)]

# Validation

df_val_hor = df[(df['Country'].isin(ctr_val_hor)) & (df['Year'] != 2015) & (df['Year'] != 2014)]
df_val_ver = df[(df['Country'].isin(ctr_val_ver)) & (df['Year'] == 2014)]

# Train

df_train = df[(~df['Country'].isin(all_ctr)) & (df['Year'] != 2015) & (df['Year'] != 2014)]

# %%
# External

X_test_hor_ext = df_test_hor_ext[X_cols]
y_test_hor_ext = df_test_hor_ext[y_col]

X_test_ver_ext = df_test_ver_ext[X_cols]
y_test_ver_ext = df_test_ver_ext[y_col]

# Internal

X_test_hor_int = df_test_hor_int[X_cols]
y_test_hor_int = df_test_hor_int[y_col]

X_test_ver_int = df_test_ver_int[X_cols]
y_test_ver_int = df_test_ver_int[y_col]

# Validation

X_val_hor = df_val_hor[X_cols]
y_val_hor = df_val_hor[y_col]

X_val_ver = df_val_ver[X_cols]
y_val_ver = df_val_ver[y_col]

# Train

X_train = df_train[X_cols]
y_train = df_train[y_col]

# %% [markdown]
# ### ii. Numerical and categorical

# %%
num_X_cols = X_cols.copy()
num_X_cols.remove('Status')

cat_X_cols = ['Status']

# %%
num_X_cols
# Out:
# ['Year',
#  'Adult Mortality',
#  'infant deaths',
#  'Alcohol',
#  'percentage expenditure',
#  'Hepatitis B',
#  'Measles ',
#  ' BMI ',
#  'under-five deaths ',
#  'Polio',
#  'Total expenditure',
#  'Diphtheria ',
#  ' HIV/AIDS',
#  'GDP',
#  'Population',
#  ' thinness  1-19 years',
#  ' thinness 5-9 years',
#  'Income composition of resources',
#  'Schooling']

# %%
cat_X_cols
# Out:
# ['Status']

# %% [markdown]
# ### iii. FillNaNs

# %%
mean_num_X_cols = X_train[num_X_cols].mean()

# %%
X_train[num_X_cols] = X_train[num_X_cols].fillna(mean_num_X_cols)
X_train['Status'] = X_train['Status'].fillna('Developing')

# %% [markdown]
# ### iv. Analysis "y" variable

# %%
y_train.hist()
plt.show()

# %%
y_train.boxplot()
plt.show()

# %% [markdown]
# ### v. Analysis "y" variable period by period

# %%
gb_y = df_train.groupby(by = ['Year'], as_index = False)['Life expectancy '].mean()

# %%
plt.plot(gb_y['Year'], gb_y['Life expectancy '], label = 'Life Expectancy')
plt.title('Life Expectancy vs Year', fontsize = 17)
plt.ylabel('Life Expectancy', fontsize = 15)
plt.xlabel('Year', fontsize = 15)
plt.show()

# %% [markdown]
# ### vi. Relation dependent variable with independent: Numerical (Spearman Correlation)

# %%
X_train_corr_num = X_train[num_X_cols].copy()
y_train_corr = y_train.copy()

# %%
X_train_corr_num = X_train_corr_num.rank(method = 'first', ascending = True)
y_train_corr = y_train_corr.rank(method = 'first', ascending = False)

# %%
spe_corr_num = []

for c_num in num_X_cols:

    spe_corr_num.append([c_num, abs(y_train_corr['Life expectancy '].corr(X_train_corr_num[c_num]))])

# %%
spe_corr_num = dict(spe_corr_num)

# %%
spe_corr_num
# Out:
# {'Year': 0.1350743541682314,
#  'Adult Mortality': 0.6630452935041735,
#  'infant deaths': 0.5936339082051267,
#  'Alcohol': 0.4206614214766979,
#  'percentage expenditure': 0.5347505713855052,
#  'Hepatitis B': 0.28831762432445207,
#  'Measles ': 0.22139901607710463,
#  ' BMI ': 0.5927082532819016,
#  'under-five deaths ': 0.616444009858386,
#  'Polio': 0.5548662043828231,
#  'Total expenditure': 0.31508934592120286,
#  'Diphtheria ': 0.5698304527461284,
#  ' HIV/AIDS': 0.7426836377202707,
#  'GDP': 0.550115507989789,
#  'Population': 0.01461151755612672,
#  ' thinness  1-19 years': 0.6377384181004172,
#  ' thinness 5-9 years': 0.6452913582354334,
#  'Income composition of resources': 0.8147647882984216,
#  'Schooling': 0.7956246125154025}

# %% [markdown]
# ### vii. Relation dependent variable with independent: Categorical (Anova)

# %%
df_train.boxplot('Life expectancy ', by = 'Status')
plt.show()

# %%
k = 2

# %%
S_1 = y_train[X_train['Status'] == 'Developed']['Life expectancy '].std()
S_2 = y_train[X_train['Status'] == 'Developing']['Life expectancy '].std()

# %%
S_1, S_2
# Out:
# (3.719361036031604, 9.52517305894413)

# %%
n_1 = (X_train['Status'] == 'Developed').sum()
n_2 = (X_train['Status'] == 'Developing').sum()

# %%
n_1, n_2
# Out:
# (308, 1288)

# %%
n_T = len(X_train)

# %%
n_T, n_1 + n_2
# Out:
# (1596, 1596)

# %%
bar_y = y_train['Life expectancy '].mean()

# %%
bar_y
# Out:
# 68.61015037593984

# %%
bar_y_1 = y_train[X_train['Status'] == 'Developed']['Life expectancy '].mean()
bar_y_2 = y_train[X_train['Status'] == 'Developing']['Life expectancy '].mean()

# %%
bar_y_1, bar_y_2
# Out:
# (79.3487012987013, 66.04223602484471)

# %%
SS_B = n_1*((bar_y_1 - bar_y)**2) + n_2*((bar_y_2 - bar_y)**2)

# %%
SS_B
# Out:
# 44010.78372314191

# %%
SS_W = (n_1 - 1)*(S_1**2) + (n_2 - 1)*(S_2**2)

# %%
SS_W
# Out:
# 121015.05184076822

# %%
MS_B = SS_B/(k - 1)

# %%
MS_B
# Out:
# 44010.78372314191

# %%
MS_W = SS_W/(n_T - k)

# %%
MS_W
# Out:
# 75.91910404063252

# %%
F_stat = MS_B/MS_W

# %%
alpha = 0.05

# %%
cdf = scipy.stats.f.cdf(F_stat, k - 1, n_T - k)

# %%
p_value = 1 - cdf

# %%
p_value
# Out:
# 1.1102230246251565e-16

# %%
p_value < alpha
# Out:
# True

# %% [markdown]
# **Comments** We only have one categorical indepedent variable and its importance is cdf.

# %% [markdown]
# ### viii. Plot the relation between dependent and independent variables: Numerical

# %%
for n_X_c in num_X_cols:

    plt.scatter(X_train[n_X_c], y_train['Life expectancy '])
    plt.title(f'{n_X_c} vs Life expectancy')
    plt.xlabel(n_X_c, fontsize = 15)
    plt.ylabel('Life expectancy ', fontsize = 15)
    plt.show()

    print('-'*90)
# Out:
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ### ix. Plot the relation between dependent and independent variables: Categorical

# %%
df_train.boxplot('Life expectancy ', by = 'Status')
plt.show()

# %%
plt.hist(df_train[df_train['Status'] == 'Developed']['Life expectancy '], alpha = 0.7, label = 'Developed', density = True)
plt.hist(df_train[df_train['Status'] == 'Developing']['Life expectancy '], alpha = 0.7, label = 'Developing', density = True)
plt.legend()
plt.show()

# %% [markdown]
# ### x. Patterns of interest

# %% [markdown]
# * Year vs Life Expectancy
# * Income composition of resources vs Life expectancy
# * GDP vs Life expectancy
# * Adult Mortality vs Life expectancy

# %% [markdown]
# ### xi. Plotting every independent variable: Numerical

# %%
for n_X_c in num_X_cols:
    X_train[n_X_c].hist(density = True)
    plt.xlabel(n_X_c, fontsize = 15)
    plt.show()
    print('-'*90)
# Out:
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ### xii. Plotting every independent variable: Categorical

# %%
X_train['Status'].value_counts()
# Out:
# Developing    1288
# Developed      308
# Name: Status, dtype: int64

# %%
round(X_train['Status'].value_counts(normalize = True)*100, 2)
# Out:
# Developing    80.7
# Developed     19.3
# Name: Status, dtype: float64

# %% [markdown]
# ### xiii. Relation between numerical independent variables (Spearman)

# %%
m_corr_num = round(abs(X_train_corr_num.corr())*100, 2)

# %%
m_corr_num.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_72bb8_row0_col0, #T_72bb8_row1_col1, #T_72bb8_row2_col2, #T_72bb8_row3_col3, #T_72bb8_row4_col4, #T_72bb8_row5_col5, #T_72bb8_row6_col6, #T_72bb8_row7_col7, #T_72bb8_row8_col8, #T_72bb8_row9_col9, #T_72bb8_row10_col10, #T_72bb8_row11_col11, #T_72bb8_row12_col12, #T_72bb8_row13_col13, #T_72bb8_row14_col14, #T_72bb8_row15_col15, #T_72bb8_row16_col16, #T_72bb8_row17_col17, #T_72bb8_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col1, #T_72bb8_row0_col2, #T_72bb8_row0_col4, #T_72bb8_row0_col6, #T_72bb8_row0_col8, #T_72bb8_row0_col12, #T_72bb8_row0_col15, #T_72bb8_row0_col16, #T_72bb8_row3_col5, #T_72bb8_row5_col3, #T_72bb8_row5_col10, #T_72bb8_row6_col13, #T_72bb8_row9_col14, #T_72bb8_row11_col14, #T_72bb8_row12_col0, #T_72bb8_row14_col7, #T_72bb8_row14_col9, #T_72bb8_row14_col11, #T_72bb8_row14_col17, #T_72bb8_row14_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col3, #T_72bb8_row10_col4, #T_72bb8_row10_col13 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col5, #T_72bb8_row3_col9, #T_72bb8_row6_col7, #T_72bb8_row9_col6, #T_72bb8_row10_col11, #T_72bb8_row12_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col9, #T_72bb8_row6_col17, #T_72bb8_row9_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col10 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col11, #T_72bb8_row5_col1, #T_72bb8_row9_col4, #T_72bb8_row10_col12 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col13 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col14, #T_72bb8_row14_col10 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col17 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_72bb8_row0_col18, #T_72bb8_row4_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_72bb8_row1_col0, #T_72bb8_row14_col0, #T_72bb8_row14_col1, #T_72bb8_row17_col14 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_72bb8_row1_col2 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_72bb8_row1_col3, #T_72bb8_row5_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_72bb8_row1_col4, #T_72bb8_row8_col14, #T_72bb8_row9_col13, #T_72bb8_row9_col15, #T_72bb8_row10_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_72bb8_row1_col5, #T_72bb8_row5_col6, #T_72bb8_row6_col15, #T_72bb8_row10_col17 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_72bb8_row1_col6, #T_72bb8_row6_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_72bb8_row1_col7, #T_72bb8_row2_col4, #T_72bb8_row8_col4, #T_72bb8_row9_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_72bb8_row1_col8, #T_72bb8_row2_col9, #T_72bb8_row7_col1, #T_72bb8_row11_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_72bb8_row1_col9 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_72bb8_row1_col10, #T_72bb8_row16_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_72bb8_row1_col11, #T_72bb8_row11_col7, #T_72bb8_row12_col13, #T_72bb8_row13_col16 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_72bb8_row1_col12, #T_72bb8_row1_col17, #T_72bb8_row8_col17, #T_72bb8_row11_col18, #T_72bb8_row17_col11 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_72bb8_row1_col13, #T_72bb8_row3_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_72bb8_row1_col14, #T_72bb8_row3_col0, #T_72bb8_row6_col0, #T_72bb8_row14_col4, #T_72bb8_row18_col14 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_72bb8_row1_col15, #T_72bb8_row11_col12, #T_72bb8_row12_col11, #T_72bb8_row17_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_72bb8_row1_col16, #T_72bb8_row8_col16 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_72bb8_row1_col18 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_72bb8_row2_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_72bb8_row2_col1, #T_72bb8_row4_col13 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_72bb8_row2_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_72bb8_row2_col5, #T_72bb8_row11_col13, #T_72bb8_row15_col13, #T_72bb8_row16_col13 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_72bb8_row2_col6, #T_72bb8_row7_col16, #T_72bb8_row8_col6, #T_72bb8_row12_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_72bb8_row2_col7, #T_72bb8_row2_col16, #T_72bb8_row15_col1, #T_72bb8_row15_col2, #T_72bb8_row16_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_72bb8_row2_col8, #T_72bb8_row8_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_72bb8_row2_col10, #T_72bb8_row14_col13 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_72bb8_row2_col11, #T_72bb8_row8_col11 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_72bb8_row2_col12 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_72bb8_row2_col13, #T_72bb8_row5_col12, #T_72bb8_row7_col4, #T_72bb8_row9_col16, #T_72bb8_row12_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_72bb8_row2_col14, #T_72bb8_row5_col8, #T_72bb8_row8_col13, #T_72bb8_row16_col9 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_72bb8_row2_col15, #T_72bb8_row15_col3, #T_72bb8_row16_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_72bb8_row2_col17, #T_72bb8_row12_col1, #T_72bb8_row16_col12 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_72bb8_row2_col18, #T_72bb8_row4_col17 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_72bb8_row3_col1, #T_72bb8_row6_col16, #T_72bb8_row13_col14, #T_72bb8_row14_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_72bb8_row3_col2, #T_72bb8_row7_col11 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_72bb8_row3_col6, #T_72bb8_row12_col10 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_72bb8_row3_col7, #T_72bb8_row14_col2, #T_72bb8_row14_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_72bb8_row3_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_72bb8_row3_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_72bb8_row3_col11, #T_72bb8_row11_col3, #T_72bb8_row12_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_72bb8_row3_col12, #T_72bb8_row6_col5, #T_72bb8_row6_col11, #T_72bb8_row10_col18 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_72bb8_row3_col13, #T_72bb8_row15_col11, #T_72bb8_row16_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_72bb8_row3_col14, #T_72bb8_row8_col0, #T_72bb8_row14_col3, #T_72bb8_row15_col0, #T_72bb8_row16_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_72bb8_row3_col15, #T_72bb8_row16_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_72bb8_row3_col16 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_72bb8_row3_col17 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_72bb8_row3_col18, #T_72bb8_row4_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_72bb8_row4_col0, #T_72bb8_row4_col10 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_72bb8_row4_col1, #T_72bb8_row13_col9 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_72bb8_row4_col3, #T_72bb8_row10_col3, #T_72bb8_row10_col16, #T_72bb8_row13_col11 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_72bb8_row4_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_72bb8_row4_col7, #T_72bb8_row4_col12, #T_72bb8_row9_col7, #T_72bb8_row11_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_72bb8_row4_col8, #T_72bb8_row9_col12, #T_72bb8_row12_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_72bb8_row4_col9, #T_72bb8_row7_col10, #T_72bb8_row17_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_72bb8_row4_col11, #T_72bb8_row11_col16 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_72bb8_row4_col14, #T_72bb8_row15_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_72bb8_row4_col15, #T_72bb8_row4_col16, #T_72bb8_row8_col9, #T_72bb8_row11_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_72bb8_row4_col18, #T_72bb8_row7_col18 {
#   background-

# %%
var_corr_num = []

for c in num_X_cols:
    corr_c = list(m_corr_num[m_corr_num[c] > 70][c].index)
    for c_j in corr_c:
        if c_j != c:
            if (([c, c_j] in var_corr_num) == False) and (([c_j, c] in var_corr_num) == False):
                var_corr_num.append([c, c_j])

# %%
var_corr_num
# Out:
# [['infant deaths', 'under-five deaths '],
#  ['Polio', 'Diphtheria '],
#  [' thinness  1-19 years', ' thinness 5-9 years'],
#  ['Income composition of resources', 'Schooling']]

# %%
del_var_num = []

for pair in var_corr_num:

    if spe_corr_num[pair[0]] > spe_corr_num[pair[1]]:

        del_var_num.append(pair[1])

    else:

        del_var_num.append(pair[0])

# %%
del_var_num = list(set(del_var_num))

# %%
del_var_num
# Out:
# ['infant deaths', 'Polio', 'Schooling', ' thinness  1-19 years']

# %%
num_X_cols = ['Year', 'Adult Mortality', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Total expenditure', 
              'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness 5-9 years', 'Income composition of resources']

# %% [markdown]
# ### xiv. Relation between categorical independent variables (Chi-Square)

# %% [markdown]
# It's not necessary because we have only one categorical variable.

# %% [markdown]
# ### xv. Encoding

# %%
X_train['Status'] = (X_train['Status'] == 'Developed')*1

# %%
round(X_train['Status'].mean()*100, 2)
# Out:
# 19.3

# %% [markdown]
# ### xvi. Relation between all variables

# %%
X_cols = ['Status', 'Year', 'Adult Mortality', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 
          'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness 5-9 years', 'Income composition of resources']

# %%
X_train_corr = X_train[X_cols].copy()
X_train_corr = X_train_corr.rank(method = 'first', ascending = True)

# %%
m_corr = abs(X_train_corr.corr()*100)

# %%
m_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_533f2_row0_col0, #T_533f2_row1_col1, #T_533f2_row2_col2, #T_533f2_row3_col3, #T_533f2_row4_col4, #T_533f2_row5_col5, #T_533f2_row6_col6, #T_533f2_row7_col7, #T_533f2_row8_col8, #T_533f2_row9_col9, #T_533f2_row10_col10, #T_533f2_row11_col11, #T_533f2_row12_col12, #T_533f2_row13_col13, #T_533f2_row14_col14, #T_533f2_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col3, #T_533f2_row3_col7, #T_533f2_row13_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_533f2_row0_col4, #T_533f2_row6_col0, #T_533f2_row9_col13 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col5, #T_533f2_row0_col11, #T_533f2_row1_col12 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col6, #T_533f2_row2_col6, #T_533f2_row6_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col7, #T_533f2_row11_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_533f2_row0_col8, #T_533f2_row5_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col9, #T_533f2_row15_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col10, #T_533f2_row7_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col12, #T_533f2_row10_col4, #T_533f2_row10_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col13, #T_533f2_row8_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_533f2_row0_col14, #T_533f2_row4_col7, #T_533f2_row4_col11, #T_533f2_row10_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_533f2_row0_col15, #T_533f2_row7_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_533f2_row1_col0, #T_533f2_row1_col2, #T_533f2_row1_col4, #T_533f2_row1_col6, #T_533f2_row1_col8, #T_533f2_row1_col11, #T_533f2_row1_col14, #T_533f2_row3_col5, #T_533f2_row5_col3, #T_533f2_row5_col9, #T_533f2_row6_col12, #T_533f2_row10_col13, #T_533f2_row11_col1, #T_533f2_row13_col0, #T_533f2_row13_col7, #T_533f2_row13_col10, #T_533f2_row13_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_533f2_row1_col3, #T_533f2_row9_col4, #T_533f2_row9_col12 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_533f2_row1_col5, #T_533f2_row6_col7, #T_533f2_row9_col10, #T_533f2_row11_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_533f2_row1_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_533f2_row1_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_533f2_row1_col10, #T_533f2_row4_col0, #T_533f2_row5_col2, #T_533f2_row9_col11 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_533f2_row1_col13, #T_533f2_row13_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_533f2_row1_col15 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_533f2_row2_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_533f2_row2_col1, #T_533f2_row13_col1, #T_533f2_row13_col2, #T_533f2_row15_col13 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_533f2_row2_col3, #T_533f2_row5_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_533f2_row2_col4, #T_533f2_row8_col13, #T_533f2_row9_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_533f2_row2_col5, #T_533f2_row5_col6, #T_533f2_row9_col0, #T_533f2_row9_col15 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_533f2_row2_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_533f2_row2_col8, #T_533f2_row7_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_533f2_row2_col9, #T_533f2_row14_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_533f2_row2_col10, #T_533f2_row10_col7, #T_533f2_row11_col12, #T_533f2_row12_col14 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_533f2_row2_col11, #T_533f2_row2_col15, #T_533f2_row8_col15, #T_533f2_row15_col10 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_533f2_row2_col12, #T_533f2_row3_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_533f2_row2_col13, #T_533f2_row3_col1, #T_533f2_row6_col1, #T_533f2_row13_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_533f2_row2_col14, #T_533f2_row8_col14 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_533f2_row3_col0, #T_533f2_row6_col13 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_533f2_row3_col2, #T_533f2_row6_col14, #T_533f2_row12_col13, #T_533f2_row13_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_533f2_row3_col6, #T_533f2_row11_col9 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_533f2_row3_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_533f2_row3_col9 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_533f2_row3_col10, #T_533f2_row10_col3, #T_533f2_row11_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_533f2_row3_col11, #T_533f2_row6_col5, #T_533f2_row6_col10, #T_533f2_row7_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_533f2_row3_col12, #T_533f2_row14_col10 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_533f2_row3_col13, #T_533f2_row8_col1, #T_533f2_row11_col0, #T_533f2_row13_col3, #T_533f2_row14_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_533f2_row3_col14 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_533f2_row3_col15 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_533f2_row4_col1, #T_533f2_row4_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_533f2_row4_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_533f2_row4_col3, #T_533f2_row9_col3, #T_533f2_row9_col14, #T_533f2_row12_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_533f2_row4_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_533f2_row4_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_533f2_row4_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_533f2_row4_col10, #T_533f2_row10_col14 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_533f2_row4_col12 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_533f2_row4_col13 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_533f2_row4_col14, #T_533f2_row10_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_533f2_row4_col15 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_533f2_row5_col0, #T_533f2_row5_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_533f2_row5_col4, #T_533f2_row13_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_533f2_row5_col7, #T_533f2_row9_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_533f2_row5_col8, #T_533f2_row8_col12 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_533f2_row5_col10, #T_533f2_row10_col5 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_533f2_row5_col11, #T_533f2_row7_col4, #T_533f2_row11_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_533f2_row5_col12, #T_533f2_row6_col9, #T_533f2_row9_col5 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_533f2_row5_col15, #T_533f2_row12_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_533f2_row6_col2, #T_533f2_row14_col13 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_533f2_row6_col3, #T_533f2_row10_col1, #T_533f2_row10_col9, #T_533f2_row15_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_533f2_row6_col8, #T_533f2_row11_col8 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_533f2_row6_col11 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_533f2_row6_col15 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_533f2_row7_col1, #T_533f2_row8_col9 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_533f2_row7_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_533f2_row7_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_533f2_row7_col9, #T_533f2_row15_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_533f2_row7_col10 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_533f2_row7_col11 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_533f2_row7_col12, #T_533f2_row14_col9 {
#   background-color: #a6c4fe;
#   color: #0

# %%
var_corr = []

for c in X_cols:
    corr_c = list(m_corr[m_corr[c] > 70][c].index)
    for c_j in corr_c:
        if c_j != c:
            if (([c, c_j] in var_corr) == False) and (([c_j, c] in var_corr) == False):
                var_corr.append([c, c_j])

# %%
var_corr
# Out:
# []

# %% [markdown]
# ### Time of execution

# %%
end = time.time()

# %%
delta = (end - start)

hours = int(delta/3600)
mins = int((delta - hours*3600)/60)
segs = int(delta - hours*3600 - mins*60)
print(f'Execute this notebook take us {hours} hours, {mins} minutes and {segs} seconds.')
# Out:
# Execute this notebook take us 0 hours, 0 minutes and 4 seconds.
