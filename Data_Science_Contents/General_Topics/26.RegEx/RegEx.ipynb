# %% [markdown]
# # RegEx

# %% [markdown]
# By Alberto Valdés
#
# **Mail 1:** anvaldes@uc.cl
#
# **Mail 2:** alberto.valdes.gonzalez.96@gmail.com

# %% [markdown]
# A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.
#
# RegEx can be used to check if a string contains the specified search pattern.

# %%
from matplotlib import image as mpimg
import matplotlib.pyplot as plt

# %%
def display_img(name, a, b):
    plt.figure(figsize = (a, b))
    image = mpimg.imread(name)
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %% [markdown]
# # 1. Import Module

# %%
import re

# %% [markdown]
# # 2. Example

# %% [markdown]
# Search the string to see if it starts with "The" and ends with "Spain":

# %%
txt = "The rain in Spain"

# %%
x = re.search("^The.*Spain$", txt)

# %%
if x:
    print('True')
else:
    print('False')
# Out:
# True

# %% [markdown]
# # 3. RegEx Functions

# %% [markdown]
# **findall**: Return a list containing all matches.
#
# **search:** Regurn a "Match object" if there is a match anywhere in the string.
#
# **split:** Returns a list where the string has been split at each match.
#
# **sub:** Replaces one or many matches with a string.

# %% [markdown]
# ### i. findall

# %%
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
txt = "The rain in Spain"
x = re.findall("oi", txt)
print(x)
# Out:
# []

# %% [markdown]
# ### ii. search

# %%
txt = "The rain in Spain"
x = re.search("\s", txt)
print(x.start())
# Out:
# 3

# %%
txt = "The rain in Spain rain"
x = re.search("rain", txt)
print(x.start())
print(x.end())
print(txt[x.start(): x.end()])
# Out:
# 4
# 8
# rain

# %%
txt = "The rain in Spain"
x = re.search("Portugal", txt)
print(x)
# Out:
# None

# %% [markdown]
# ### iii. split

# %%
txt = "The rain in Spain"
x = re.split("\s", txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']

# %%
txt = "The rain in Spain"
x = re.split("\s", txt, 1) # Only the first occurrence
print(x)
# Out:
# ['The', 'rain in Spain']

# %% [markdown]
# ### iv. sub

# %%
txt = "The rain in Spain"
x = re.sub("\s", "9", txt)
print(x)
# Out:
# The9rain9in9Spain

# %%
txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2) # The first two occurrences
print(x)
# Out:
# The9rain9in Spain

# %%
txt = "The rain in Spain"
x = re.sub("b", "9", txt, 2)
print(x)
# Out:
# The rain in Spain

# %% [markdown]
# # 4. Special sequences

# %% [markdown]
# A special sequence is a \ followed by one of the characters in the list below, and has a special meaning:

# %%
display_img('Special_Sequences.png', 17, 15)

# %% [markdown]
# # 5. Sets

# %% [markdown]
# A set is a set of characters inside a pair of square brackets [] with a special meaning:

# %%
display_img('Sets.png', 17, 15)
