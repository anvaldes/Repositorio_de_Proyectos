# %% [markdown]
# ### Open CV Contours

# %% [markdown]
# By Alberto Valdés
#
# **Mail 1:** anvaldes@uc.cl
#
# **Mail 2:** alberto.valdes.gonzalez.96@gmail.com

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import cv2
import time
import matplotlib.pyplot as plt
from skimage import img_as_ubyte

# %% [markdown]
# ### Start time of execution

# %%
start = time.time()

# %% [markdown]
# # Execution

# %% [markdown]
# ### 1. Open image

# %%
img = cv2.imread("img.png")

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### 2. Convert to gray

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap = 'gray')
plt.show()

# %% [markdown]
# ### 3. Binarize the image

# %%
img_bin = (gray >= 230)*255
img_bin = img_as_ubyte(img_bin)

# %%
plt.imshow(img_bin, cmap = 'gray')
plt.show()

# %% [markdown]
# ### 4. Extract the contour

# %%
contours, heirarchy = cv2.findContours(img_bin, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %% [markdown]
# ### 5. Plot the contour

# %%
_ = cv2.drawContours(img, contours, -1, (0,255,0), 20)

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Time of execution

# %%
end = time.time()

# %%
delta = (end - start)

hours = int(delta/3600)
mins = int((delta - hours*3600)/60)
segs = int(delta - hours*3600 - mins*60)
print(f'Execute this notebook take us {hours} hours, {mins} minutes and {segs} seconds.')
# Out:
# Execute this notebook take us 0 hours, 0 minutes and 0 seconds.
