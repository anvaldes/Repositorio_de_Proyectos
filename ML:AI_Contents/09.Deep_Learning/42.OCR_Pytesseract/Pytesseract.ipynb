# %% [markdown]
# ### Pytesseract

# %% [markdown]
# By Alberto Valdés
#
# **Mail 1:** anvaldes@uc.cl
#
# **Mail 2:** alberto.valdes.gonzalez.96@gmail.com

# %%
import cv2
import time
import pytesseract
from pytesseract import Output
import matplotlib.pyplot as plt

# %% [markdown]
# ### Start time of execution

# %%
start = time.time()

# %% [markdown]
# ### 1. Read image

# %%
easy_text_path = "images/easy_text.png"
easy_img = cv2.imread(easy_text_path)

# %%
plt.imshow(easy_img)
plt.show()

# %% [markdown]
# ### 2. Using the OCR

# %%
text = pytesseract.image_to_string(easy_img)
print(text)
# Out:
# This text is
# easy to extract.

# %%
data = pytesseract.image_to_data(easy_img, output_type=Output.DICT)

# %%
n_boxes = len(data["text"])

# %% [markdown]
# ### 3. Ploting the Bounding Boxes

# %%
for i in range(n_boxes):
   if data["conf"][i] == -1:
       continue
   # Coordinates
   x, y = data["left"][i], data["top"][i]
   w, h = data["width"][i], data["height"][i]

   # Corners
   top_left = (x, y)
   bottom_right = (x + w, y + h)

   # Box params
   green = (0, 255, 0)
   thickness = 3  # pixels

   cv2.rectangle(img = easy_img, pt1 = top_left, pt2 = bottom_right, color = green, thickness = thickness)

# %%
plt.imshow(easy_img)
plt.show()

# %% [markdown]
# ### Time of execution

# %%
end = time.time()

# %%
delta = (end - start)

hours = int(delta/3600)
mins = int((delta - hours*3600)/60)
segs = int(delta - hours*3600 - mins*60)
print(f'Execute this notebook take us {hours} hours, {mins} minutes and {segs} seconds.')
# Out:
# Execute this notebook take us 0 hours, 0 minutes and 0 seconds.
